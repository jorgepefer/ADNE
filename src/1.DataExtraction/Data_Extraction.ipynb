# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt



def borrar_archivo(nombre_archivo):
    if os.path.exists(nombre_archivo):
        os.remove(nombre_archivo)

# %% [markdown]
# ### HISTOGRAMAS

# %%
import os

def generar_histograma_aleatorio(carpeta_destino ):
    distribuciones = ['normal', 'uniform', 'exponential', 'gamma', 'lognormal', 'weibull', 'chi_squared']
    distribucion_elegida = random.choice(distribuciones)
    
    if distribucion_elegida == 'normal':
        media = random.uniform(-5, 5)
        desviacion = random.uniform(0.5, 3)
        datos = np.random.normal(media, desviacion, 1000)
        folder_path = 'normal_histograms'
    elif distribucion_elegida == 'uniform':
        inicio = random.uniform(-10, 0)
        fin = random.uniform(0, 10)
        datos = np.random.uniform(inicio, fin, 1000)
        folder_path = 'uniform_histograms'
    elif distribucion_elegida == 'exponential':
        escala = random.uniform(0.5, 2)
        datos = np.random.exponential(escala, 1000)
        folder_path = 'exponential_histograms'
    elif distribucion_elegida == 'gamma':
        forma = random.uniform(1, 5)
        escala = random.uniform(0.5, 2)
        datos = np.random.gamma(forma, escala, 1000)
        folder_path = 'gamma_histograms'
    elif distribucion_elegida == 'lognormal':
        media = random.uniform(-2, 2)
        sigma = random.uniform(0.1, 1)
        datos = np.random.lognormal(media, sigma, 1000)
        folder_path = 'lognormal_histograms'
    elif distribucion_elegida == 'weibull':
        forma = random.uniform(1, 5)
        escala = random.uniform(0.5, 2)
        datos = np.random.weibull(forma, 1000) * escala
        folder_path = 'weibull_histograms'
    elif distribucion_elegida == 'chi_squared':
        grados_libertad = random.randint(1, 10)
        datos = np.random.chisquare(grados_libertad, 1000)
        folder_path = 'chi_squared_histograms'
    num_bins = random.randint(5, 50)
    
    color = np.random.rand(3,)
    
    plt.hist(datos, bins=num_bins, color=color, edgecolor='black')
    plt.title(f'Histograma Aleatorio ({distribucion_elegida.capitalize()})')
    plt.xlabel('Valor')
    plt.ylabel('Frecuencia')
    

    carpeta_destino=os.path.join(carpeta_destino,folder_path)
    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)
    nombre_archivo = f'histograma_{random.randint(1, 1000000)}.png'
    nombre_archivo = os.path.join(carpeta_destino, nombre_archivo)
    borrar_archivo(nombre_archivo)  # Solo si existe   
    plt.savefig(nombre_archivo)
    plt.close()
    
    return nombre_archivo

# %%
def descargar_histogramas(num_descargas, carpeta_destino):

    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)
   
    
    for i in range(num_descargas):
        nombre_archivo = generar_histograma_aleatorio(carpeta_destino)
        print(f"Descargado {nombre_archivo}")

# %%
os.chdir('c:\\Users\\LOLI\\Desktop\\ICAI\\2º SEMESTRE\\NO ESTRUCURADOS\\TRABAJO FINAL\\ADNE\\data')

num_descargas=5000
carpeta_destino='histogramas'
descargar_histogramas(num_descargas,carpeta_destino)
# Out:
# Descargado histogramas\gamma_histograms\histograma_880607.png
# Descargado histogramas\lognormal_histograms\histograma_68371.png
# Descargado histogramas\weibull_histograms\histograma_236601.png
# Descargado histogramas\uniform_histograms\histograma_512235.png
# Descargado histogramas\weibull_histograms\histograma_935572.png
# Descargado histogramas\chi_squared_histograms\histograma_944117.png
# Descargado histogramas\lognormal_histograms\histograma_523519.png
# Descargado histogramas\normal_histograms\histograma_745089.png
# Descargado histogramas\normal_histograms\histograma_633615.png
# Descargado histogramas\uniform_histograms\histograma_222718.png
# Descargado histogramas\normal_histograms\histograma_21634.png
# Descargado histogramas\normal_histograms\histograma_801331.png
# Descargado histogramas\weibull_histograms\histograma_825426.png
# Descargado histogramas\exponential_histograms\histograma_733186.png
# Descargado histogramas\lognormal_histograms\histograma_506585.png
# Descargado histogramas\exponential_histograms\histograma_959329.png
# Descargado histogramas\lognormal_histograms\histograma_843874.png
# Descargado histogramas\gamma_histograms\histograma_380185.png
# Descargado histogramas\chi_squared_histograms\histograma_882933.png
# Descargado histogramas\uniform_histograms\histograma_898544.png
# Descargado histogramas\chi_squared_histograms\histograma_935487.png
# Descargado histogramas\normal_histograms\histograma_784340.png
# Descargado histogramas\weibull_histograms\histograma_723408.png
# Descargado histogramas\uniform_histograms\histograma_273722.png
# Descargado histogramas\chi_squared_histograms\histograma_102310.png
# Descargado histogramas\gamma_histograms\histograma_728998.png
# Descargado histogramas\chi_squared_histograms\histograma_501591.png
# Descargado histogramas\weibull_histograms\histograma_886015.png
# Descargado histogramas\chi_squared_histograms\histograma_513051.png
# Descargado histogramas\lognormal_histograms\histograma_560984.png
# Descargado histogramas\lognormal_histograms\histograma_173220.png
# Descargado histogramas\weibull_histograms\histograma_519824.png
# Descargado histogramas\gamma_histograms\histograma_133537.png
# Descargado histogramas\chi_squared_histograms\histograma_745914.png
# Descargado histogramas\lognormal_histograms\histograma_243915.png
# Descargado histogramas\normal_histograms\histograma_882929.png
# Descargado histogramas\normal_histograms\histograma_515298.png
# Descargado histogramas\weibull_histograms\histograma_164507.png
# Descargado histogramas\lognormal_histograms\histograma_210515.png
# Descargado histogramas\uniform_histograms\histograma_563987.png
# Descargado histogramas\gamma_histograms\histograma_338601.png
# Descargado histogramas\gamma_histograms\histograma_37346.png
# Descargado histogramas\weibull_histograms\histograma_866080.png
# Descargado histogramas\exponential_histograms\histograma_740122.png
# Descargado histogramas\weibull_histograms\histograma_820750.png
# Descargado histogramas\weibull_histograms\histograma_126911.png
# Descargado histogramas\uniform_histograms\histograma_983558.png
# Descargado histogramas\lognormal_histograms\histograma_974100.png
# Descargado histogramas\weibull_histograms\histograma_195541.png
# Descargado histogramas\normal_histograms\histograma_305015.png
# Descargado histogramas\gamma_histograms\histograma_280735.png
# Descargado histogramas\uniform_histograms\histograma_681144.png
# Descargado histogramas\gamma_histograms\histograma_522755.png
# Descargado histogramas\exponential_histograms\histograma_427765.png
# Descargado histogramas\exponential_histograms\histograma_662024.png
# Descargado histogramas\weibull_histograms\histograma_278360.png
# Descargado histogramas\chi_squared_histograms\histograma_558784.png
# Descargado histogramas\gamma_histograms\histograma_71593.png
# Descargado histogramas\exponential_histograms\histograma_839699.png
# Descargado histogramas\weibull_histograms\histograma_885815.png
# Descargado histogramas\weibull_histograms\histograma_785443.png
# Descargado histogramas\weibull_histograms\histograma_280640.png
# Descargado histogramas\exponential_histograms\histograma_846427.png
# Descargado histogramas\chi_squared_histograms\histograma_320842.png
# Descargado histogramas\weibull_histograms\histograma_412075.png
# Descargado histogramas\chi_squared_histograms\histograma_525627.png
# Descargado histogramas\weibull_histograms\histograma_600114.png
# Descargado histogramas\weibull_histograms\histograma_225154.png
# Descargado histogramas\uniform_histograms\histograma_722673.png
# Descargado histogramas\weibull_histograms\histograma_13926.png
# Descargado histogramas\exponential_histograms\histograma_897973.png
# Descargado histogramas\gamma_histograms\histograma_328021.png
# Descargado histogramas\exponential_histograms\histograma_538067.png
# Descargado histogramas\weibull_histograms\histograma_451605.png
# Descargado histogramas\lognormal_histograms\histograma_414559.png
# Descargado histogramas\uniform_histograms\histograma_247944.png
# Descargado histogramas\lognormal_histograms\histograma_919330.png
# Descargado histogramas\weibull_histograms\histograma_915694.png
# Descargado histogramas\normal_histograms\histograma_555414.png
# Descargado histogramas\gamma_histograms\histograma_370689.png
# Descargado histogramas\gamma_histograms\histograma_278274.png
# Descargado histogramas\uniform_histograms\histograma_585779.png
# Descargado histogramas\exponential_histograms\histograma_348836.png
# Descargado histogramas\lognormal_histograms\histograma_443370.png
# Descargado histogramas\gamma_histograms\histograma_926290.png
# Descargado histogramas\normal_histograms\histograma_678848.png
# Descargado histogramas\chi_squared_histograms\histograma_134944.png
# Descargado histogramas\chi_squared_histograms\histograma_684714.png
# Descargado histogramas\weibull_histograms\histograma_629169.png
# Descargado histogramas\chi_squared_histograms\histograma_220248.png
# Descargado histogramas\chi_squared_histograms\histograma_796533.png
# Descargado histogramas\exponential_histograms\histograma_913155.png
# Descargado histogramas\exponential_histograms\histograma_915517.png
# Descargado histogramas\gamma_histograms\histograma_403957.png
# Descargado histogramas\exponential_histograms\histograma_695649.png
# Descargado histogramas\normal_histograms\histograma_29577.png
# Descargado histogramas\exponential_histograms\histograma_944104.png
# Descargado histogramas\lognormal_histograms\histograma_57787.png
# Descargado histogramas\gamma_histograms\histograma_883264.png
# Descargado histogramas\lognormal_histograms\histograma_844405.png
# Descargado histogramas\exponential_histograms\histograma_33535.png
# Descargado histogramas\normal_histograms\histograma_397287.png
# Descargado histogramas\exponential_histograms\histograma_134025.png
# Descargado histogramas\uniform_histograms\histograma_102428.png
# Descargado histogramas\weibull_histograms\histograma_92799.png
# Descargado histogramas\gamma_histograms\histograma_26112.png
# Descargado histogramas\lognormal_histograms\histograma_711498.png
# Descargado histogramas\chi_squared_histograms\histograma_925570.png
# Descargado histogramas\weibull_histograms\histograma_680315.png
# Descargado histogramas\uniform_histograms\histograma_582204.png
# Descargado histogramas\weibull_histograms\histograma_907082.png
# Descargado histogramas\exponential_histograms\histograma_812030.png
# Descargado histogramas\chi_squared_histograms\histograma_755055.png
# Descargado histogramas\gamma_histograms\histograma_923008.png
# Descargado histogramas\exponential_histograms\histograma_547335.png
# Descargado histogramas\uniform_histograms\histograma_815379.png
# Descargado histogramas\lognormal_histograms\histograma_729974.png
# Descargado histogramas\uniform_histograms\histograma_139170.png
# Descargado histogramas\gamma_histograms\histograma_217078.png
# Descargado histogramas\gamma_histograms\histograma_988339.png
# Descargado histogramas\lognormal_histograms\histograma_619772.png
# Descargado histogramas\exponential_histograms\histograma_481684.png
# Descargado histogramas\weibull_histograms\histograma_694404.png
# Descargado histogramas\gamma_histograms\histograma_508088.png
# Descargado histogramas\normal_histograms\histograma_782438.png
# Descargado histogramas\exponential_histograms\histograma_566285.png
# Descargado histogramas\gamma_histograms\histograma_826675.png
# Descargado histogramas\chi_squared_histograms\histograma_11641.png
# Descargado histogramas\exponential_histograms\histograma_913991.png
# Descargado histogramas\gamma_histograms\histograma_463620.png
# Descargado histogramas\chi_squared_histograms\histograma_559520.png
# Descargado histogramas\uniform_histograms\histograma_982610.png
# Descargado histogramas\weibull_histograms\histograma_260609.png
# Descargado histogramas\weibull_histograms\histograma_691795.png
# Descargado histogramas\exponential_histograms\histograma_577814.png
# Descargado histogramas\gamma_histograms\histograma_269292.png
# Descargado histogramas\lognormal_histograms\histograma_684129.png
# Descargado histogramas\normal_histograms\histograma_443707.png
# Descargado histogramas\lognormal_histograms\histograma_32120.png
# Descargado histogramas\normal_histograms\histograma_659846.png
# Descargado histogramas\exponential_histograms\histograma_525767.png
# Descargado histogramas\lognormal_histograms\histograma_307976.png
# Descargado histogramas\normal_histograms\histograma_897600.png
# Descargado histogramas\gamma_histograms\histograma_546272.png
# Descargado histogramas\normal_histograms\histograma_616075.png
# Descargado histogramas\uniform_histograms\histograma_900635.png
# Descargado histogramas\lognormal_histograms\histograma_465622.png
# Descargado histogramas\chi_squared_histograms\histograma_729094.png
# Descargado histogramas\exponential_histograms\histograma_873572.png
# Descargado histogramas\weibull_histograms\histograma_980483.png
# Descargado histogramas\exponential_histograms\histograma_561338.png
# Descargado histogramas\gamma_histograms\histograma_663221.png
# Descargado histogramas\lognormal_histograms\histograma_791781.png
# Descargado histogramas\lognormal_histograms\histograma_194184.png
# Descargado histogramas\weibull_histograms\histograma_537391.png
# Descargado histogramas\chi_squared_histograms\histograma_749967.png
# Descargado histogramas\lognormal_histograms\histograma_198861.png
# Descargado histogramas\exponential_histograms\histograma_337538.png
# Descargado histogramas\lognormal_histograms\histograma_531152.png
# Descargado histogramas\chi_squared_histograms\histograma_904930.png
# Descargado histogramas\gamma_histograms\histograma_2026.png
# Descargado histogramas\exponential_histograms\histograma_975048.png
# Descargado histogramas\weibull_histograms\histograma_107168.png
# Descargado histogramas\weibull_histograms\histograma_796452.png
# Descargado histogramas\uniform_histograms\histograma_539616.png
# Descargado histogramas\exponential_histograms\histograma_498751.png
# Descargado histogramas\lognormal_histograms\histograma_308303.png
# Descargado histogramas\lognormal_histograms\histograma_369636.png
# Descargado histogramas\gamma_histograms\histograma_320812.png
# Descargado histogramas\normal_histograms\histograma_251888.png
# Descargado histogramas\gamma_histograms\histograma_470820.png
# Descargado histogramas\chi_squared_histograms\histograma_809624.png
# Descargado histogramas\uniform_histograms\histograma_641304.png
# Descargado histogramas\lognormal_histograms\histograma_989290.png
# Descargado histogramas\normal_histograms\histograma_483732.png
# Descargado histogramas\chi_squared_histograms\histograma_798254.png
# Descargado histogramas\normal_histograms\histograma_326204.png
# Descargado histogramas\exponential_histograms\histograma_515635.png
# Descargado histogramas\uniform_histograms\histograma_376848.png
# Descargado histogramas\chi_squared_histograms\histograma_229339.png
# Descargado histogramas\weibull_histograms\histograma_531878.png
# Descargado histogramas\exponential_histograms\histograma_180111.png
# Descargado histogramas\gamma_histograms\histograma_762612.png
# Descargado histogramas\gamma_histograms\histograma_112091.png
# Descargado histogramas\lognormal_histograms\histograma_638132.png
# Descargado histogramas\weibull_histograms\histograma_656350.png
# Descargado histogramas\lognormal_histograms\histograma_941289.png
# Descargado histogramas\lognormal_histograms\histograma_346152.png
# Descargado histogramas\lognormal_histograms\histograma_481173.png
# Descargado histogramas\normal_histograms\histograma_978102.png
# Descargado histogramas\exponential_histograms\histograma_78216.png
# Descargado histogramas\gamma_histograms\histograma_790957.png
# Descargado histogramas\chi_squared_histograms\histograma_959585.png
# Descargado histogramas\lognormal_histograms\histograma_631083.png
# Descargado histogramas\uniform_histograms\histograma_627953.png
# Descargado histogramas\uniform_histograms\histograma_2968.png
# Descargado histogramas\normal_histograms\histograma_433581.png
# Descargado histogramas\lognormal_histograms\histograma_958141.png
# Descargado histogramas\gamma_histograms\histograma_122235.png
# Descargado histogramas\normal_histograms\histograma_1245.png
# Descargado histogramas\lognormal_histograms\histograma_131739.png
# Descargado histogramas\normal_histograms\histograma_324743.png
# Descargado histogramas\lognormal_histograms\histograma_32350.png
# Descargado histogramas\lognormal_histograms\histograma_887634.png
# Descargado histogramas\gamma_histograms\histograma_457567.png
# Descargado histogramas\weibull_histograms\histograma_718685.png
# Descargado histogramas\gamma_histograms\histograma_146132.png
# Descargado histogramas\lognormal_histograms\histograma_80145.png
# Descargado histogramas\weibull_histograms\histograma_231262.png
# Descargado histogramas\chi_squared_histograms\histograma_193642.png
# Descargado histogramas\normal_histograms\histograma_979278.png
# Descargado histogramas\chi_squared_histograms\histograma_719710.png
# Descargado histogramas\normal_histograms\histograma_562236.png
# Descargado histogramas\lognormal_histograms\histograma_356808.png
# Descargado histogramas\gamma_histograms\histograma_569606.png
# Descargado histogramas\normal_histograms\histograma_318863.png
# Descargado histogramas\exponential_histograms\histograma_481921.png
# Descargado histogramas\lognormal_histograms\histograma_477970.png
# Descargado histogramas\exponential_histograms\histograma_101064.png
# Descargado histogramas\chi_squared_histograms\histograma_580152.png
# Descargado histogramas\gamma_histograms\histograma_65884.png
# Descargado histogramas\lognormal_histograms\histograma_91368.png
# Descargado histogramas\gamma_histograms\histograma_348195.png
# Descargado histogramas\lognormal_histograms\histograma_609905.png
# Descargado histogramas\lognormal_histograms\histograma_787571.png
# Descargado histogramas\exponential_histograms\histograma_614477.png
# Descargado histogramas\normal_histograms\histograma_707730.png
# Descargado histogramas\normal_histograms\histograma_461887.png
# Descargado histogramas\weibull_histograms\histograma_120755.png
# Descargado histogramas\gamma_histograms\histograma_739534.png
# Descargado histogramas\chi_squared_histograms\histograma_613410.png
# Descargado histogramas\lognormal_histograms\histograma_365986.png
# Descargado histogramas\normal_histograms\histograma_967266.png
# Descargado histogramas\gamma_histograms\histograma_639959.png
# Descargado histogramas\normal_histograms\histograma_458105.png
# Descargado histogramas\lognormal_histograms\histograma_664959.png
# Descargado histogramas\gamma_histograms\histograma_473932.png
# Descargado histogramas\uniform_histograms\histograma_292194.png
# Descargado histogramas\uniform_histograms\histograma_836999.png
# Descargado histogramas\gamma_histograms\histograma_845666.png
# Descargado histogramas\lognormal_histograms\histograma_760883.png
# Descargado histogramas\lognormal_histograms\histograma_856215.png
# Descargado histogramas\exponential_histograms\histograma_700134.png
# Descargado histogramas\gamma_histograms\histograma_830886.png
# Descargado histogramas\exponential_histograms\histograma_310838.png
# Descargado histogramas\weibull_histograms\histograma_395648.png
# Descargado histogramas\lognormal_histograms\histograma_492802.png
# Descargado histogramas\gamma_histograms\histograma_276579.png
# Descargado histogramas\normal_histograms\histograma_729826.png
# Descargado histogramas\chi_squared_histograms\histograma_615614.png
# Descargado histogramas\gamma_histograms\histograma_938627.png
# Descargado histogramas\exponential_histograms\histograma_689587.png
# Descargado histogramas\uniform_histograms\histograma_232422.png
# Descargado histogramas\exponential_histograms\histograma_593650.png
# Descargado histogramas\exponential_histograms\histograma_350317.png
# Descargado histogramas\weibull_histograms\histograma_9282.png
# Descargado histogramas\gamma_histograms\histograma_88355.png
# Descargado histogramas\lognormal_histograms\histograma_87469.png
# Descargado histogramas\uniform_histograms\histograma_910784.png
# Descargado histogramas\uniform_histograms\histograma_41498.png
# Descargado histogramas\chi_squared_histograms\histograma_838754.png
# Descargado histogramas\chi_squared_histograms\histograma_103552.png
# Descargado histogramas\exponential_histograms\histograma_663643.png
# Descargado histogramas\weibull_histograms\histograma_315573.png
# Descargado histogramas\weibull_histograms\histograma_271771.png
# Descargado histogramas\exponential_histograms\histograma_709983.png
# Descargado histogramas\chi_squared_histograms\histograma_216923.png
# Descargado histogramas\chi_squared_histograms\histograma_618235.png
# Descargado histogramas\uniform_histograms\histograma_864182.png
# Descargado histogramas\weibull_histograms\histograma_644488.png
# Descargado histogramas\weibull_histograms\histograma_300300.png
# Descargado histogramas\weibull_histograms\histograma_94732.png
# Descargado histogramas\chi_squared_histograms\histograma_705860.png
# Descargado histogramas\uniform_histograms\histograma_697870.png
# Descargado histogramas\gamma_histograms\histograma_325177.png
# Descargado histogramas\weibull_histograms\histograma_220715.png
# Descargado histogramas\weibull_histograms\histograma_819632.png
# Descargado histogramas\uniform_histograms\histograma_177828.png
# Descargado histogramas\exponential_histograms\histograma_693279.png
# Descargado histogramas\chi_squared_histograms\histograma_989299.png
# Descargado histogramas\gamma_histograms\histograma_592448.png
# Descargado histogramas\chi_squared_histograms\histograma_683191.png
# Descargado histogramas\gamma_histograms\histograma_889006.png
# Descargado histogramas\gamma_histograms\histograma_255978.png
# Descargado histogramas\weibull_histograms\histograma_845820.png
# Descargado histogramas\exponential_histograms\histograma_586545.png
# Descargado histogramas\weibull_histograms\histograma_767754.png
# Descargado histogramas\gamma_histograms\histograma_426798.png
# Descargado histogramas\gamma_histograms\histograma_851182.png
# Descargado histogramas\lognormal_histograms\histograma_946915.png
# Descargado histogramas\normal_histograms\histograma_570921.png
# Descargado histogramas\uniform_histograms\histograma_133035.png
# Descargado histogramas\exponential_histograms\histograma_438603.png
# Descargado histogramas\weibull_histograms\histograma_898910.png
# Descargado histogramas\uniform_histograms\histograma_405407.png
# Descargado histogramas\lognormal_histograms\histograma_37799.png
# Descargado histogramas\normal_histograms\histograma_869996.png
# Descargado histogramas\uniform_histograms\histograma_244744.png
# Descargado histogramas\gamma_histograms\histograma_268646.png
# Descargado histogramas\weibull_histograms\histograma_176905.png
# Descargado histogramas\uniform_histograms\histograma_467050.png
# Descargado histogramas\weibull_histograms\histograma_850257.png
# Descargado histogramas\exponential_histograms\histograma_534033.png
# Descargado histogramas\chi_squared_histograms\histograma_497784.png
# Descargado histogramas\lognormal_histograms\histograma_12143.png
# Descargado histogramas\weibull_histograms\histograma_747708.png
# Descargado histogramas\weibull_histograms\histograma_242235.png
# Descargado histogramas\uniform_histograms\histograma_53193.png
# Descargado histogramas\normal_histograms\histograma_238536.png
# Descargado histogramas\uniform_histograms\histograma_547051.png
# Descargado histogramas\weibull_histograms\histograma_91052.png
# Descargado histogramas\exponential_histograms\histograma_91559.png
# Descargado histogramas\chi_squared_histograms\histograma_572691.png
# Descargado histogramas\gamma_histograms\histograma_431901.png
# Descargado histogramas\chi_squared_histograms\histograma_165447.png
# Descargado histogramas\uniform_histograms\histograma_821973.png
# Descargado histogramas\weibull_histograms\histograma_49681.png
# Descargado histogramas\weibull_histograms\histograma_765169.png
# Descargado histogramas\weibull_histograms\histograma_889133.png
# Descargado histogramas\chi_squared_histograms\histograma_103350.png
# Descargado histogramas\weibull_histograms\histograma_243373.png
# Descargado histogramas\uniform_histograms\histograma_452658.png
# Descargado histogramas\weibull_histograms\histograma_961054.png
# Descargado histogramas\weibull_histograms\histograma_951341.png
# Descargado histogramas\exponential_histograms\histograma_206299.png
# Descargado histogramas\chi_squared_histograms\histograma_121408.png
# Descargado histogramas\chi_squared_histograms\histograma_803239.png
# Descargado histogramas\lognormal_histograms\histograma_504084.png
# Descargado histogramas\gamma_histograms\histograma_686448.png
# Descargado histogramas\exponential_histograms\histograma_349137.png
# Descargado histogramas\uniform_histograms\histograma_633383.png
# Descargado histogramas\weibull_histograms\histograma_528093.png
# Descargado histogramas\normal_histograms\histograma_503078.png
# Descargado histogramas\lognormal_histograms\histograma_811142.png
# Descargado histogramas\lognormal_histograms\histograma_370857.png
# Descargado histogramas\weibull_histograms\histograma_477063.png
# Descargado histogramas\exponential_histograms\histograma_507176.png
# Descargado histogramas\lognormal_histograms\histograma_765409.png
# Descargado histogramas\weibull_histograms\histograma_166753.png
# Descargado histogramas\normal_histograms\histograma_703360.png
# Descargado histogramas\exponential_histograms\histograma_550495.png
# Descargado histogramas\weibull_histograms\histograma_446613.png
# Descargado histogramas\lognormal_histograms\histograma_762248.png
# Descargado histogramas\normal_histograms\histograma_83354.png
# Descargado histogramas\exponential_histograms\histograma_260352.png
# Descargado histogramas\gamma_histograms\histograma_825042.png
# Descargado histogramas\exponential_histograms\histograma_300713.png
# Descargado histogramas\chi_squared_histograms\histograma_77700.png
# Descargado histogramas\exponential_histograms\histograma_743907.png
# Descargado histogramas\gamma_histograms\histograma_121078.png
# Descargado histogramas\normal_histograms\histograma_600097.png
# Descargado histogramas\gamma_histograms\histograma_14987.png
# Descargado histogramas\normal_histograms\histograma_454128.png
# Descargado histogramas\gamma_histograms\histograma_91438.png
# Descargado histogramas\exponential_histograms\histograma_386728.png
# Descargado histogramas\normal_histograms\histograma_780093.png
# Descargado histogramas\weibull_histograms\histograma_355349.png
# Descargado histogramas\chi_squared_histograms\histograma_943945.png
# Descargado histogramas\uniform_histograms\histograma_945332.png
# Descargado histogramas\lognormal_histograms\histograma_25324.png
# Descargado histogramas\uniform_histograms\histograma_913349.png
# Descargado histogramas\chi_squared_histograms\histograma_962179.png
# Descargado histogramas\weibull_histograms\histograma_285548.png
# Descargado histogramas\lognormal_histograms\histograma_805628.png
# Descargado histogramas\exponential_histograms\histograma_669054.png
# Descargado histogramas\gamma_histograms\histograma_110331.png
# Descargado histogramas\uniform_histograms\histograma_71801.png
# Descargado histogramas\normal_histograms\histograma_549427.png
# Descargado histogramas\exponential_histograms\histograma_778219.png
# Descargado histogramas\lognormal_histograms\histograma_825955.png
# Descargado histogramas\gamma_histograms\histograma_938305.png
# Descargado histogramas\chi_squared_histograms\histograma_877629.png
# Descargado histogramas\gamma_histograms\histograma_336942.png
# Descargado histogramas\weibull_histograms\histograma_703515.png
# Descargado histogramas\uniform_histograms\histograma_186882.png
# Descargado histogramas\uniform_histograms\histograma_178416.png
# Descargado histogramas\weibull_histograms\histograma_458392.png
# Descargado histogramas\weibull_histograms\histograma_83931.png
# Descargado histogramas\exponential_histograms\histograma_733057.png
# Descargado histogramas\weibull_histograms\histograma_106778.png
# Descargado histogramas\chi_squared_histograms\histograma_955940.png
# Descargado histogramas\uniform_histograms\histograma_359404.png
# Descargado histogramas\gamma_histograms\histograma_797408.png
# Descargado histogramas\lognormal_histograms\histograma_481160.png
# Descargado histogramas\uniform_histograms\histograma_256714.png
# Descargado histogramas\gamma_histograms\histograma_861795.png
# Descargado histogramas\chi_squared_histograms\histograma_14303.png
# Descargado histogramas\exponential_histograms\histograma_265868.png
# Descargado histogramas\exponential_histograms\histograma_544225.png
# Descargado histogramas\lognormal_histograms\histograma_114179.png
# Descargado histogramas\weibull_histograms\histograma_372552.png
# Descargado histogramas\normal_histograms\histograma_162767.png
# Descargado histogramas\lognormal_histograms\histograma_671971.png
# Descargado histogramas\chi_squared_histograms\histograma_151910.png
# Descargado histogramas\uniform_histograms\histograma_653288.png
# Descargado histogramas\weibull_histograms\histograma_543226.png
# Descargado histogramas\normal_histograms\histograma_676973.png
# Descargado histogramas\exponential_histograms\histograma_177434.png
# Descargado histogramas\normal_histograms\histograma_371853.png
# Descargado histogramas\chi_squared_histograms\histograma_243529.png
# Descargado histogramas\exponential_histograms\histograma_805639.png
# Descargado histogramas\gamma_histograms\histograma_834807.png
# Descargado histogramas\uniform_histograms\histograma_26985.png
# Descargado histogramas\chi_squared_histograms\histograma_552532.png
# Descargado histogramas\uniform_histograms\histograma_296665.png
# Descargado histogramas\uniform_histograms\histograma_705564.png
# Descargado histogramas\exponential_histograms\histograma_317468.png
# Descargado histogramas\lognormal_histograms\histograma_323455.png
# Descargado histogramas\exponential_histograms\histograma_116692.png
# Descargado histogramas\uniform_histograms\histograma_522864.png
# Descargado histogramas\gamma_histograms\histograma_524792.png
# Descargado histogramas\chi_squared_histograms\histograma_259221.png
# Descargado histogramas\chi_squared_histograms\histograma_166449.png
# Descargado histogramas\uniform_histograms\histograma_154707.png
# Descargado histogramas\weibull_histograms\histograma_198370.png
# Descargado histogramas\gamma_histograms\histograma_832840.png
# Descargado histogramas\lognormal_histograms\histograma_218266.png
# Descargado histogramas\normal_histograms\histograma_837526.png
# Descargado histogramas\normal_histograms\histograma_943777.png
# Descargado histogramas\normal_histograms\histograma_720174.png
# Descargado histogramas\lognormal_histograms\histograma_411431.png
# Descargado histogramas\uniform_histograms\histograma_823172.png
# Descargado histogramas\normal_histograms\histograma_972928.png
# Descargado histogramas\exponential_histograms\histograma_336152.png
# Descargado histogramas\weibull_histograms\histograma_466024.png
# Descargado histogramas\weibull_histograms\histograma_142274.png
# Descargado histogramas\uniform_histograms\histograma_876546.png
# Descargado histogramas\weibull_histograms\histograma_984816.png
# Descargado histogramas\weibull_histograms\histograma_194150.png
# Descargado histogramas\lognormal_histograms\histograma_274730.png
# Descargado histogramas\lognormal_histograms\histograma_372317.png
# Descargado histogramas\lognormal_histograms\histograma_753466.png
# Descargado histogramas\normal_histograms\histograma_841106.png
# Descargado histogramas\lognormal_histograms\histograma_263342.png
# Descargado histogramas\exponential_histograms\histograma_494501.png
# Descargado histogramas\chi_squared_histograms\histograma_349639.png
# Descargado histogramas\exponential_histograms\histograma_669899.png
# Descargado histogramas\uniform_histograms\histograma_527805.png
# Descargado histogramas\exponential_histograms\histograma_679770.png
# Descargado histogramas\uniform_histograms\histograma_442581.png
# Descargado histogramas\uniform_histograms\histograma_927388.png
# Descargado histogramas\weibull_histograms\histograma_211130.png
# Descargado histogramas\chi_squared_histograms\histograma_156156.png
# Descargado histogramas\normal_histograms\histograma_348700.png
# Descargado histogramas\gamma_histograms\histograma_521552.png
# Descargado histogramas\normal_histograms\histograma_256729.png
# Descargado histogramas\gamma_histograms\histograma_186785.png
# Descargado histogramas\chi_squared_histograms\histograma_136518.png
# Descargado histogramas\weibull_histograms\histograma_588381.png
# Descargado histogramas\chi_squared_histograms\histograma_464935.png
# Descargado histogramas\lognormal_histograms\histograma_549568.png
# Descargado histogramas\exponential_histograms\histograma_157924.png
# Descargado histogramas\normal_histograms\histograma_106060.png
# Descargado histogramas\normal_histograms\histograma_759941.png
# Descargado histogramas\weibull_histograms\histograma_919181.png
# Descargado histogramas\chi_squared_histograms\histograma_351550.png
# Descargado histogramas\uniform_histograms\histograma_978193.png
# Descargado histogramas\gamma_histograms\histograma_944659.png
# Descargado histogramas\exponential_histograms\histograma_249394.png
# Descargado histogramas\chi_squared_histograms\histograma_250051.png
# Descargado histogramas\uniform_histograms\histograma_891886.png
# Descargado histogramas\exponential_histograms\histograma_5583.png
# Descargado histogramas\gamma_histograms\histograma_421900.png
# Descargado histogramas\gamma_histograms\histograma_373087.png
# Descargado histogramas\chi_squared_histograms\histograma_653433.png
# Descargado histogramas\uniform_histograms\histograma_681450.png
# Descargado histogramas\normal_histograms\histograma_642965.png
# Descargado histogramas\normal_histograms\histograma_764257.png
# Descargado histogramas\lognormal_histograms\histograma_859237.png
# Descargado histogramas\uniform_histograms\histograma_261175.png
# Descargado histogramas\uniform_histograms\histograma_328425.png
# Descargado histogramas\weibull_histograms\histograma_10807.png
# Descargado histogramas\gamma_histograms\histograma_251411.png
# Descargado histogramas\gamma_histograms\histograma_237058.png
# Descargado histogramas\gamma_histograms\histograma_401949.png
# Descargado histogramas\exponential_histograms\histograma_841096.png
# Descargado histogramas\lognormal_histograms\histograma_269706.png
# Descargado histogramas\uniform_histograms\histograma_886074.png
# Descargado histogramas\lognormal_histograms\histograma_956507.png
# Descargado histogramas\gamma_histograms\histograma_657667.png
# Descargado histogramas\gamma_histograms\histograma_384268.png
# Descargado histogramas\lognormal_histograms\histograma_100017.png
# Descargado histogramas\uniform_histograms\histograma_79055.png
# Descargado histogramas\uniform_histograms\histograma_456795.png
# Descargado histogramas\uniform_histograms\histograma_236486.png
# Descargado histogramas\normal_histograms\histograma_79582.png
# Descargado histogramas\gamma_histograms\histograma_459831.png
# Descargado histogramas\chi_squared_histograms\histograma_639982.png
# Descargado histogramas\uniform_histograms\histograma_248859.png
# Descargado histogramas\lognormal_histograms\histograma_424966.png
# Descargado histogramas\weibull_histograms\histograma_690393.png
# Descargado histogramas\chi_squared_histograms\histograma_567552.png
# Descargado histogramas\lognormal_histograms\histograma_284793.png
# Descargado histogramas\uniform_histograms\histograma_220985.png
# Descargado histogramas\normal_histograms\histograma_206007.png
# Descargado histogramas\normal_histograms\histograma_561444.png
# Descargado histogramas\uniform_histograms\histograma_608243.png
# Descargado histogramas\weibull_histograms\histograma_875424.png
# Descargado histogramas\normal_histograms\histograma_937318.png
# Descargado histogramas\weibull_histograms\histograma_501183.png
# Descargado histogramas\weibull_histograms\histograma_336515.png
# Descargado histogramas\chi_squared_histograms\histograma_409281.png
# Descargado histogramas\weibull_histograms\histograma_542609.png
# Descargado histogramas\uniform_histograms\histograma_635376.png
# Descargado histogramas\gamma_histograms\histograma_668928.png
# Descargado histogramas\uniform_histograms\histograma_440262.png
# Descargado histogramas\uniform_histograms\histograma_459502.png
# Descargado histogramas\weibull_histograms\histograma_233060.png
# Descargado histogramas\normal_histograms\histograma_333702.png
# Descargado histogramas\lognormal_histograms\histograma_710442.png
# Descargado histogramas\uniform_histograms\histograma_308098.png
# Descargado histogramas\gamma_histograms\histograma_814366.png
# Descargado histogramas\chi_squared_histograms\histograma_745827.png
# Descargado histogramas\gamma_histograms\histograma_33934.png
# Descargado histogramas\weibull_histograms\histograma_23919.png
# Descargado histogramas\chi_squared_histograms\histograma_391611.png
# Descargado histogramas\weibull_histograms\histograma_29985.png
# Descargado histogramas\gamma_histograms\histograma_341835.png
# Descargado histogramas\gamma_histograms\histograma_739069.png
# Descargado histogramas\normal_histograms\histograma_165530.png
# Descargado histogramas\uniform_histograms\histograma_663606.png
# Descargado histogramas\lognormal_histograms\histograma_140256.png
# Descargado histogramas\normal_histograms\histograma_56400.png
# Descargado histogramas\normal_histograms\histograma_376524.png
# Descargado histogramas\weibull_histograms\histograma_839512.png
# Descargado histogramas\gamma_histograms\histograma_740683.png
# Descargado histogramas\normal_histograms\histograma_95153.png
# Descargado histogramas\exponential_histograms\histograma_382660.png
# Descargado histogramas\gamma_histograms\histograma_273617.png
# Descargado histogramas\lognormal_histograms\histograma_529650.png
# Descargado histogramas\lognormal_histograms\histograma_948187.png
# Descargado histogramas\weibull_histograms\histograma_343447.png
# Descargado histogramas\uniform_histograms\histograma_836141.png
# Descargado histogramas\chi_squared_histograms\histograma_68793.png
# Descargado histogramas\exponential_histograms\histograma_973125.png
# Descargado histogramas\gamma_histograms\histograma_959461.png
# Descargado histogramas\exponential_histograms\histograma_282111.png
# Descargado histogramas\gamma_histograms\histograma_31498.png
# Descargado histogramas\exponential_histograms\histograma_315907.png
# Descargado histogramas\weibull_histograms\histograma_385604.png
# Descargado histogramas\normal_histograms\histograma_757525.png
# Descargado histogramas\lognormal_histograms\histograma_538717.png
# Descargado histogramas\weibull_histograms\histograma_797107.png
# Descargado histogramas\lognormal_histograms\histograma_198852.png
# Descargado histogramas\gamma_histograms\histograma_468069.png
# Descargado histogramas\uniform_histograms\histograma_503551.png
# Descargado histogramas\normal_histograms\histograma_570644.png
# Descargado histogramas\gamma_histograms\histograma_88636.png
# Descargado histogramas\exponential_histograms\histograma_797935.png
# Descargado histogramas\uniform_histograms\histograma_786812.png
# Descargado histogramas\weibull_histograms\histograma_582257.png
# Descargado histogramas\chi_squared_histograms\histograma_96243.png
# Descargado histogramas\normal_histograms\histograma_837224.png
# Descargado histogramas\normal_histograms\histograma_84338.png
# Descargado histogramas\chi_squared_histograms\histograma_300114.png
# Descargado histogramas\weibull_histograms\histograma_325489.png
# Descargado histogramas\weibull_histograms\histograma_78163.png
# Descargado histogramas\normal_histograms\histograma_12655.png
# Descargado histogramas\normal_histograms\histograma_666039.png
# Descargado histogramas\normal_histograms\histograma_911091.png
# Descargado histogramas\gamma_histograms\histograma_434532.png
# Descargado histogramas\weibull_histograms\histograma_726263.png
# Descargado histogramas\exponential_histograms\histograma_106143.png
# Descargado histogramas\gamma_histograms\histograma_784124.png
# Descargado histogramas\lognormal_histograms\histograma_337996.png
# Descargado histogramas\uniform_histograms\histograma_450016.png
# Descargado histogramas\gamma_histograms\histograma_603887.png
# Descargado histogramas\gamma_histograms\histograma_895271.png
# Descargado histogramas\chi_squared_histograms\histograma_432730.png
# Descargado histogramas\weibull_histograms\histograma_324503.png
# Descargado histogramas\gamma_histograms\histograma_483310.png
# Descargado histogramas\normal_histograms\histograma_764112.png
# Descargado histogramas\gamma_histograms\histograma_583423.png
# Descargado histogramas\gamma_histograms\histograma_281148.png
# Descargado histogramas\uniform_histograms\histograma_672580.png
# Descargado histogramas\exponential_histograms\histograma_92475.png
# Descargado histogramas\gamma_histograms\histograma_483368.png
# Descargado histogramas\uniform_histograms\histograma_207859.png
# Descargado histogramas\uniform_histograms\histograma_684269.png
# Descargado histogramas\weibull_histograms\histograma_878350.png
# Descargado histogramas\exponential_histograms\histograma_31731.png
# Descargado histogramas\gamma_histograms\histograma_441697.png
# Descargado histogramas\gamma_histograms\histograma_360710.png
# Descargado histogramas\normal_histograms\histograma_666211.png
# Descargado histogramas\uniform_histograms\histograma_950621.png
# Descargado histogramas\normal_histograms\histograma_221954.png
# Descargado histogramas\normal_histograms\histograma_784815.png
# Descargado histogramas\exponential_histograms\histograma_996583.png
# Descargado histogramas\uniform_histograms\histograma_769657.png
# Descargado histogramas\chi_squared_histograms\histograma_676523.png
# Descargado histogramas\weibull_histograms\histograma_117902.png
# Descargado histogramas\lognormal_histograms\histograma_660278.png
# Descargado histogramas\uniform_histograms\histograma_121927.png
# Descargado histogramas\lognormal_histograms\histograma_999492.png
# Descargado histogramas\gamma_histograms\histograma_212745.png
# Descargado histogramas\chi_squared_histograms\histograma_559805.png
# Descargado histogramas\chi_squared_histograms\histograma_77623.png
# Descargado histogramas\normal_histograms\histograma_272386.png
# Descargado histogramas\normal_histograms\histograma_660732.png
# Descargado histogramas\gamma_histograms\histograma_907399.png
# Descargado histogramas\exponential_histograms\histograma_688233.png
# Descargado histogramas\uniform_histograms\histograma_783858.png
# Descargado histogramas\gamma_histograms\histograma_727153.png
# Descargado histogramas\chi_squared_histograms\histograma_287484.png
# Descargado histogramas\gamma_histograms\histograma_160135.png
# Descargado histogramas\exponential_histograms\histograma_504776.png
# Descargado histogramas\uniform_histograms\histograma_331981.png
# Descargado histogramas\uniform_histograms\histograma_235400.png
# Descargado histogramas\gamma_histograms\histograma_857461.png
# Descargado histogramas\uniform_histograms\histograma_860072.png
# Descargado histogramas\normal_histograms\histograma_113612.png
# Descargado histogramas\chi_squared_histograms\histograma_322818.png
# Descargado histogramas\gamma_histograms\histograma_997001.png
# Descargado histogramas\lognormal_histograms\histograma_417085.png
# Descargado histogramas\lognormal_histograms\histograma_938824.png
# Descargado histogramas\weibull_histograms\histograma_479487.png
# Descargado histogramas\exponential_histograms\histograma_39956.png
# Descargado histogramas\gamma_histograms\histograma_528422.png
# Descargado histogramas\chi_squared_histograms\histograma_511443.png
# Descargado histogramas\uniform_histograms\histograma_89118.png
# Descargado histogramas\lognormal_histograms\histograma_281080.png
# Descargado histogramas\weibull_histograms\histograma_147862.png
# Descargado histogramas\gamma_histograms\histograma_506850.png
# Descargado histogramas\lognormal_histograms\histograma_858987.png
# Descargado histogramas\normal_histograms\histograma_428230.png
# Descargado histogramas\uniform_histograms\histograma_314454.png
# Descargado histogramas\normal_histograms\histograma_851200.png
# Descargado histogramas\exponential_histograms\histograma_970639.png
# Descargado histogramas\normal_histograms\histograma_429799.png
# Descargado histogramas\chi_squared_histograms\histograma_851087.png
# Descargado histogramas\uniform_histograms\histograma_312497.png
# Descargado histogramas\exponential_histograms\histograma_634216.png
# Descargado histogramas\lognormal_histograms\histograma_257581.png
# Descargado histogramas\lognormal_histograms\histograma_781567.png
# Descargado histogramas\lognormal_histograms\histograma_753063.png
# Descargado histogramas\exponential_histograms\histograma_943426.png
# Descargado histogramas\chi_squared_histograms\histograma_210403.png
# Descargado histogramas\normal_histograms\histograma_708945.png
# Descargado histogramas\uniform_histograms\histograma_311437.png
# Descargado histogramas\uniform_histograms\histograma_719162.png
# Descargado histogramas\chi_squared_histograms\histograma_665744.png
# Descargado histogramas\uniform_histograms\histograma_698214.png
# Descargado histogramas\lognormal_histograms\histograma_497403.png
# Descargado histogramas\gamma_histograms\histograma_336832.png
# Descargado histogramas\uniform_histograms\histograma_300109.png
# Descargado histogramas\weibull_histograms\histograma_587391.png
# Descargado histogramas\uniform_histograms\histograma_731282.png
# Descargado histogramas\normal_histograms\histograma_147741.png
# Descargado histogramas\chi_squared_histograms\histograma_660679.png
# Descargado histogramas\lognormal_histograms\histograma_181162.png
# Descargado histogramas\exponential_histograms\histograma_643672.png
# Descargado histogramas\uniform_histograms\histograma_173686.png
# Descargado histogramas\uniform_histograms\histograma_225956.png
# Descargado histogramas\chi_squared_histograms\histograma_479583.png
# Descargado histogramas\chi_squared_histograms\histograma_844360.png
# Descargado histogramas\gamma_histograms\histograma_84131.png
# Descargado histogramas\chi_squared_histograms\histograma_638671.png
# Descargado histogramas\normal_histograms\histograma_155696.png
# Descargado histogramas\uniform_histograms\histograma_523170.png
# Descargado histogramas\gamma_histograms\histograma_134607.png
# Descargado histogramas\normal_histograms\histograma_887814.png
# Descargado histogramas\chi_squared_histograms\histograma_337244.png
# Descargado histogramas\exponential_histograms\histograma_922783.png
# Descargado histogramas\gamma_histograms\histograma_639176.png
# Descargado histogramas\chi_squared_histograms\histograma_295331.png
# Descargado histogramas\weibull_histograms\histograma_67741.png
# Descargado histogramas\exponential_histograms\histograma_665124.png
# Descargado histogramas\chi_squared_histograms\histograma_63906.png
# Descargado histogramas\gamma_histograms\histograma_864857.png
# Descargado histogramas\gamma_histograms\histograma_8410.png
# Descargado histogramas\gamma_histograms\histograma_188779.png
# Descargado histogramas\weibull_histograms\histograma_485407.png
# Descargado histogramas\weibull_histograms\histograma_57212.png
# Descargado histogramas\uniform_histograms\histograma_34802.png
# Descargado histogramas\gamma_histograms\histograma_775177.png
# Descargado histogramas\gamma_histograms\histograma_313882.png
# Descargado histogramas\gamma_histograms\histograma_807817.png
# Descargado histogramas\lognormal_histograms\histograma_587007.png
# Descargado histogramas\weibull_histograms\histograma_769826.png
# Descargado histogramas\uniform_histograms\histograma_785358.png
# Descargado histogramas\exponential_histograms\histograma_305101.png
# Descargado histogramas\uniform_histograms\histograma_474346.png
# Descargado histogramas\weibull_histograms\histograma_354032.png
# Descargado histogramas\lognormal_histograms\histograma_575269.png
# Descargado histogramas\gamma_histograms\histograma_566541.png
# Descargado histogramas\lognormal_histograms\histograma_278103.png
# Descargado histogramas\weibull_histograms\histograma_174216.png
# Descargado histogramas\uniform_histograms\histograma_246142.png
# Descargado histogramas\uniform_histograms\histograma_233883.png
# Descargado histogramas\lognormal_histograms\histograma_29460.png
# Descargado histogramas\lognormal_histograms\histograma_563934.png
# Descargado histogramas\uniform_histograms\histograma_265473.png
# Descargado histogramas\weibull_histograms\histograma_482544.png
# Descargado histogramas\normal_histograms\histograma_524300.png
# Descargado histogramas\weibull_histograms\histograma_410904.png
# Descargado histogramas\uniform_histograms\histograma_654933.png
# Descargado histogramas\gamma_histograms\histograma_733847.png
# Descargado histogramas\lognormal_histograms\histograma_810769.png
# Descargado histogramas\weibull_histograms\histograma_250609.png
# Descargado histogramas\lognormal_histograms\histograma_604268.png
# Descargado histogramas\weibull_histograms\histograma_559444.png
# Descargado histogramas\chi_squared_histograms\histograma_946621.png
# Descargado histogramas\lognormal_histograms\histograma_164340.png
# Descargado histogramas\gamma_histograms\histograma_329161.png
# Descargado histogramas\lognormal_histograms\histograma_659657.png
# Descargado histogramas\weibull_histograms\histograma_986333.png
# Descargado histogramas\gamma_histograms\histograma_618919.png
# Descargado histogramas\uniform_histograms\histograma_742400.png
# Descargado histogramas\exponential_histograms\histograma_712433.png
# Descargado histogramas\chi_squared_histograms\histograma_364980.png
# Descargado histogramas\lognormal_histograms\histograma_604602.png
# Descargado histogramas\normal_histograms\histograma_498295.png
# Descargado histogramas\lognormal_histograms\histograma_687982.png
# Descargado histogramas\lognormal_histograms\histograma_570144.png
# Descargado histogramas\uniform_histograms\histograma_405469.png
# Descargado histogramas\uniform_histograms\histograma_23092.png
# Descargado histogramas\exponential_histograms\histograma_40844.png
# Descargado histogramas\lognormal_histograms\histograma_934038.png
# Descargado histogramas\weibull_histograms\histograma_592836.png
# Descargado histogramas\chi_squared_histograms\histograma_554166.png
# Descargado histogramas\weibull_histograms\histograma_983163.png
# Descargado histogramas\normal_histograms\histograma_422037.png
# Descargado histogramas\uniform_histograms\histograma_38384.png
# Descargado histogramas\lognormal_histograms\histograma_319229.png
# Descargado histogramas\weibull_histograms\histograma_961002.png
# Descargado histogramas\weibull_histograms\histograma_774161.png
# Descargado histogramas\gamma_histograms\histograma_80770.png
# Descargado histogramas\normal_histograms\histograma_803014.png
# Descargado histogramas\uniform_histograms\histograma_47765.png
# Descargado histogramas\weibull_histograms\histograma_156471.png
# Descargado histogramas\gamma_histograms\histograma_988695.png
# Descargado histogramas\uniform_histograms\histograma_611278.png
# Descargado histogramas\weibull_histograms\histograma_49498.png
# Descargado histogramas\lognormal_histograms\histograma_524958.png
# Descargado histogramas\uniform_histograms\histograma_783614.png
# Descargado histogramas\lognormal_histograms\histograma_108523.png
# Descargado histogramas\weibull_histograms\histograma_194614.png
# Descargado histogramas\normal_histograms\histograma_153763.png
# Descargado histogramas\uniform_histograms\histograma_505092.png
# Descargado histogramas\weibull_histograms\histograma_676212.png
# Descargado histogramas\gamma_histograms\histograma_419724.png
# ...
# Descargado histogramas\weibull_histograms\histograma_946753.png
# Descargado histogramas\weibull_histograms\histograma_385219.png
# Descargado histogramas\gamma_histograms\histograma_639778.png
# Descargado histogramas\exponential_histograms\histograma_951560.png
# Descargado histogramas\uniform_histograms\histograma_228820.png
# Descargado histogramas\normal_histograms\histograma_113372.png
# Descargado histogramas\exponential_histograms\histograma_635597.png
# Descargado histogramas\uniform_histograms\histograma_614902.png
# Descargado histogramas\gamma_histograms\histograma_395471.png
# Descargado histogramas\chi_squared_histograms\histograma_959853.png
# Descargado histogramas\uniform_histograms\histograma_442859.png
# Descargado histogramas\lognormal_histograms\histograma_944924.png
# Descargado histogramas\uniform_histograms\histograma_484521.png
# Descargado histogramas\lognormal_histograms\histograma_982754.png
# Descargado histogramas\gamma_histograms\histograma_100469.png
# Descargado histogramas\chi_squared_histograms\histograma_141578.png
# Descargado histogramas\exponential_histograms\histograma_462032.png
# Descargado histogramas\exponential_histograms\histograma_102972.png
# Descargado histogramas\exponential_histograms\histograma_310513.png
# Descargado histogramas\normal_histograms\histograma_344970.png
# Descargado histogramas\gamma_histograms\histograma_587365.png
# Descargado histogramas\exponential_histograms\histograma_380121.png
# Descargado histogramas\uniform_histograms\histograma_799329.png
# Descargado histogramas\uniform_histograms\histograma_739826.png
# Descargado histogramas\weibull_histograms\histograma_58813.png
# Descargado histogramas\gamma_histograms\histograma_236254.png
# Descargado histogramas\lognormal_histograms\histograma_689025.png
# Descargado histogramas\chi_squared_histograms\histograma_108873.png
# Descargado histogramas\weibull_histograms\histograma_854198.png
# Descargado histogramas\lognormal_histograms\histograma_764445.png
# Descargado histogramas\uniform_histograms\histograma_486876.png
# Descargado histogramas\exponential_histograms\histograma_25271.png
# Descargado histogramas\lognormal_histograms\histograma_90001.png
# Descargado histogramas\weibull_histograms\histograma_561208.png
# Descargado histogramas\chi_squared_histograms\histograma_805324.png
# Descargado histogramas\chi_squared_histograms\histograma_583911.png
# Descargado histogramas\lognormal_histograms\histograma_124365.png
# Descargado histogramas\uniform_histograms\histograma_129167.png
# Descargado histogramas\gamma_histograms\histograma_525668.png
# Descargado histogramas\weibull_histograms\histograma_890343.png
# Descargado histogramas\exponential_histograms\histograma_277833.png
# Descargado histogramas\uniform_histograms\histograma_525225.png
# Descargado histogramas\lognormal_histograms\histograma_41457.png
# Descargado histogramas\lognormal_histograms\histograma_638462.png
# Descargado histogramas\gamma_histograms\histograma_161019.png
# Descargado histogramas\normal_histograms\histograma_477062.png
# Descargado histogramas\gamma_histograms\histograma_918888.png
# Descargado histogramas\uniform_histograms\histograma_953126.png
# Descargado histogramas\uniform_histograms\histograma_668074.png
# Descargado histogramas\chi_squared_histograms\histograma_908090.png
# Descargado histogramas\lognormal_histograms\histograma_833945.png
# Descargado histogramas\normal_histograms\histograma_251133.png
# Descargado histogramas\chi_squared_histograms\histograma_287326.png
# Descargado histogramas\chi_squared_histograms\histograma_814454.png
# Descargado histogramas\chi_squared_histograms\histograma_133358.png
# Descargado histogramas\uniform_histograms\histograma_313760.png
# Descargado histogramas\chi_squared_histograms\histograma_715084.png
# Descargado histogramas\weibull_histograms\histograma_985402.png
# Descargado histogramas\exponential_histograms\histograma_685026.png
# Descargado histogramas\exponential_histograms\histograma_755623.png
# Descargado histogramas\exponential_histograms\histograma_549134.png
# Descargado histogramas\uniform_histograms\histograma_103875.png
# Descargado histogramas\uniform_histograms\histograma_77145.png
# Descargado histogramas\exponential_histograms\histograma_416617.png
# Descargado histogramas\lognormal_histograms\histograma_8274.png
# Descargado histogramas\normal_histograms\histograma_79341.png
# Descargado histogramas\normal_histograms\histograma_167136.png
# Descargado histogramas\exponential_histograms\histograma_196308.png
# Descargado histogramas\exponential_histograms\histograma_442020.png
# Descargado histogramas\exponential_histograms\histograma_77353.png
# Descargado histogramas\lognormal_histograms\histograma_161942.png
# Descargado histogramas\chi_squared_histograms\histograma_620849.png
# Descargado histogramas\lognormal_histograms\histograma_188589.png
# Descargado histogramas\normal_histograms\histograma_921068.png
# Descargado histogramas\lognormal_histograms\histograma_964569.png
# Descargado histogramas\normal_histograms\histograma_163615.png
# Descargado histogramas\uniform_histograms\histograma_126897.png
# Descargado histogramas\chi_squared_histograms\histograma_506.png
# Descargado histogramas\weibull_histograms\histograma_531840.png
# Descargado histogramas\normal_histograms\histograma_206116.png
# Descargado histogramas\normal_histograms\histograma_26882.png
# Descargado histogramas\exponential_histograms\histograma_283286.png
# Descargado histogramas\chi_squared_histograms\histograma_612598.png
# Descargado histogramas\normal_histograms\histograma_453159.png
# Descargado histogramas\chi_squared_histograms\histograma_466573.png
# Descargado histogramas\lognormal_histograms\histograma_73984.png
# Descargado histogramas\lognormal_histograms\histograma_21822.png
# Descargado histogramas\normal_histograms\histograma_897676.png
# Descargado histogramas\lognormal_histograms\histograma_179608.png
# Descargado histogramas\weibull_histograms\histograma_367607.png
# Descargado histogramas\weibull_histograms\histograma_874982.png
# Descargado histogramas\normal_histograms\histograma_721102.png
# Descargado histogramas\chi_squared_histograms\histograma_694577.png
# Descargado histogramas\normal_histograms\histograma_822875.png
# Descargado histogramas\chi_squared_histograms\histograma_912328.png
# Descargado histogramas\lognormal_histograms\histograma_848456.png
# Descargado histogramas\lognormal_histograms\histograma_890667.png
# Descargado histogramas\uniform_histograms\histograma_318368.png
# Descargado histogramas\uniform_histograms\histograma_372741.png
# Descargado histogramas\weibull_histograms\histograma_163336.png
# Descargado histogramas\normal_histograms\histograma_103959.png
# Descargado histogramas\uniform_histograms\histograma_254134.png
# Descargado histogramas\lognormal_histograms\histograma_161000.png
# Descargado histogramas\gamma_histograms\histograma_956493.png
# Descargado histogramas\normal_histograms\histograma_511727.png
# Descargado histogramas\uniform_histograms\histograma_274892.png
# Descargado histogramas\exponential_histograms\histograma_897760.png
# Descargado histogramas\lognormal_histograms\histograma_120730.png
# Descargado histogramas\exponential_histograms\histograma_831851.png
# Descargado histogramas\gamma_histograms\histograma_7182.png
# Descargado histogramas\uniform_histograms\histograma_15601.png
# Descargado histogramas\uniform_histograms\histograma_938826.png
# Descargado histogramas\normal_histograms\histograma_740406.png
# Descargado histogramas\lognormal_histograms\histograma_312043.png
# Descargado histogramas\lognormal_histograms\histograma_15210.png
# Descargado histogramas\exponential_histograms\histograma_877854.png
# Descargado histogramas\weibull_histograms\histograma_642300.png
# Descargado histogramas\gamma_histograms\histograma_18986.png
# Descargado histogramas\weibull_histograms\histograma_55327.png
# Descargado histogramas\exponential_histograms\histograma_994131.png
# Descargado histogramas\chi_squared_histograms\histograma_341975.png
# Descargado histogramas\chi_squared_histograms\histograma_636797.png
# Descargado histogramas\exponential_histograms\histograma_713651.png
# Descargado histogramas\uniform_histograms\histograma_576310.png
# Descargado histogramas\chi_squared_histograms\histograma_556487.png
# Descargado histogramas\uniform_histograms\histograma_427060.png
# Descargado histogramas\weibull_histograms\histograma_297668.png
# Descargado histogramas\lognormal_histograms\histograma_700255.png
# Descargado histogramas\gamma_histograms\histograma_451214.png
# Descargado histogramas\chi_squared_histograms\histograma_592852.png
# Descargado histogramas\uniform_histograms\histograma_601442.png
# Descargado histogramas\lognormal_histograms\histograma_108747.png
# Descargado histogramas\normal_histograms\histograma_626844.png
# Descargado histogramas\weibull_histograms\histograma_982708.png
# Descargado histogramas\chi_squared_histograms\histograma_589904.png
# Descargado histogramas\normal_histograms\histograma_662703.png
# Descargado histogramas\lognormal_histograms\histograma_675391.png
# Descargado histogramas\weibull_histograms\histograma_395967.png
# Descargado histogramas\weibull_histograms\histograma_500142.png
# Descargado histogramas\chi_squared_histograms\histograma_649330.png
# Descargado histogramas\normal_histograms\histograma_574609.png
# Descargado histogramas\normal_histograms\histograma_960045.png
# Descargado histogramas\gamma_histograms\histograma_156717.png
# Descargado histogramas\chi_squared_histograms\histograma_61902.png
# Descargado histogramas\weibull_histograms\histograma_60995.png
# Descargado histogramas\weibull_histograms\histograma_594773.png
# Descargado histogramas\normal_histograms\histograma_180954.png
# Descargado histogramas\gamma_histograms\histograma_407093.png
# Descargado histogramas\gamma_histograms\histograma_115950.png
# Descargado histogramas\chi_squared_histograms\histograma_621816.png
# Descargado histogramas\weibull_histograms\histograma_620348.png
# Descargado histogramas\uniform_histograms\histograma_381065.png
# Descargado histogramas\lognormal_histograms\histograma_502639.png
# Descargado histogramas\weibull_histograms\histograma_619455.png
# Descargado histogramas\gamma_histograms\histograma_767334.png
# Descargado histogramas\chi_squared_histograms\histograma_194920.png
# Descargado histogramas\weibull_histograms\histograma_386943.png
# Descargado histogramas\uniform_histograms\histograma_693399.png
# Descargado histogramas\chi_squared_histograms\histograma_727175.png
# Descargado histogramas\exponential_histograms\histograma_84978.png
# Descargado histogramas\exponential_histograms\histograma_677386.png
# Descargado histogramas\uniform_histograms\histograma_750060.png
# Descargado histogramas\gamma_histograms\histograma_57154.png
# Descargado histogramas\exponential_histograms\histograma_664334.png
# Descargado histogramas\normal_histograms\histograma_797253.png
# Descargado histogramas\lognormal_histograms\histograma_945793.png
# Descargado histogramas\chi_squared_histograms\histograma_207156.png
# Descargado histogramas\exponential_histograms\histograma_990066.png
# Descargado histogramas\exponential_histograms\histograma_989926.png
# Descargado histogramas\weibull_histograms\histograma_147693.png
# Descargado histogramas\weibull_histograms\histograma_209307.png
# Descargado histogramas\gamma_histograms\histograma_412426.png
# Descargado histogramas\normal_histograms\histograma_752412.png
# Descargado histogramas\exponential_histograms\histograma_281501.png
# Descargado histogramas\chi_squared_histograms\histograma_95118.png
# Descargado histogramas\exponential_histograms\histograma_513230.png
# Descargado histogramas\gamma_histograms\histograma_145759.png
# Descargado histogramas\lognormal_histograms\histograma_413735.png
# Descargado histogramas\weibull_histograms\histograma_114189.png
# Descargado histogramas\chi_squared_histograms\histograma_280618.png
# Descargado histogramas\chi_squared_histograms\histograma_471143.png
# Descargado histogramas\gamma_histograms\histograma_482241.png
# Descargado histogramas\lognormal_histograms\histograma_900531.png
# Descargado histogramas\weibull_histograms\histograma_269192.png
# Descargado histogramas\chi_squared_histograms\histograma_658302.png
# Descargado histogramas\normal_histograms\histograma_692846.png
# Descargado histogramas\weibull_histograms\histograma_10255.png
# Descargado histogramas\chi_squared_histograms\histograma_96676.png
# Descargado histogramas\normal_histograms\histograma_394374.png
# Descargado histogramas\exponential_histograms\histograma_650523.png
# Descargado histogramas\lognormal_histograms\histograma_674330.png
# Descargado histogramas\gamma_histograms\histograma_319473.png
# Descargado histogramas\weibull_histograms\histograma_127844.png
# Descargado histogramas\normal_histograms\histograma_970664.png
# Descargado histogramas\lognormal_histograms\histograma_534095.png
# Descargado histogramas\uniform_histograms\histograma_373951.png
# Descargado histogramas\exponential_histograms\histograma_705901.png
# Descargado histogramas\exponential_histograms\histograma_679454.png
# Descargado histogramas\weibull_histograms\histograma_173208.png
# Descargado histogramas\exponential_histograms\histograma_356423.png
# Descargado histogramas\exponential_histograms\histograma_723846.png
# Descargado histogramas\normal_histograms\histograma_998370.png
# Descargado histogramas\uniform_histograms\histograma_277294.png
# Descargado histogramas\weibull_histograms\histograma_396014.png
# Descargado histogramas\uniform_histograms\histograma_435996.png
# Descargado histogramas\gamma_histograms\histograma_752893.png
# Descargado histogramas\uniform_histograms\histograma_964505.png
# Descargado histogramas\gamma_histograms\histograma_644407.png
# Descargado histogramas\exponential_histograms\histograma_979430.png
# Descargado histogramas\chi_squared_histograms\histograma_364649.png
# Descargado histogramas\lognormal_histograms\histograma_999692.png
# Descargado histogramas\lognormal_histograms\histograma_961654.png
# Descargado histogramas\weibull_histograms\histograma_361979.png
# Descargado histogramas\normal_histograms\histograma_156086.png
# Descargado histogramas\chi_squared_histograms\histograma_152176.png
# Descargado histogramas\exponential_histograms\histograma_904211.png
# Descargado histogramas\weibull_histograms\histograma_565937.png
# Descargado histogramas\uniform_histograms\histograma_590817.png
# Descargado histogramas\gamma_histograms\histograma_408130.png
# Descargado histogramas\chi_squared_histograms\histograma_983370.png
# Descargado histogramas\normal_histograms\histograma_668727.png
# Descargado histogramas\lognormal_histograms\histograma_691409.png
# Descargado histogramas\lognormal_histograms\histograma_300155.png
# Descargado histogramas\uniform_histograms\histograma_661406.png
# Descargado histogramas\normal_histograms\histograma_276064.png
# Descargado histogramas\weibull_histograms\histograma_79692.png
# Descargado histogramas\lognormal_histograms\histograma_129464.png
# Descargado histogramas\exponential_histograms\histograma_7470.png
# Descargado histogramas\normal_histograms\histograma_638527.png
# Descargado histogramas\uniform_histograms\histograma_555841.png
# Descargado histogramas\lognormal_histograms\histograma_510921.png
# Descargado histogramas\normal_histograms\histograma_163827.png
# Descargado histogramas\normal_histograms\histograma_397857.png
# Descargado histogramas\exponential_histograms\histograma_709862.png
# Descargado histogramas\normal_histograms\histograma_878495.png
# Descargado histogramas\chi_squared_histograms\histograma_252926.png
# Descargado histogramas\exponential_histograms\histograma_539229.png
# Descargado histogramas\gamma_histograms\histograma_480015.png
# Descargado histogramas\normal_histograms\histograma_295281.png
# Descargado histogramas\normal_histograms\histograma_242105.png
# Descargado histogramas\chi_squared_histograms\histograma_459713.png
# Descargado histogramas\chi_squared_histograms\histograma_903750.png
# Descargado histogramas\exponential_histograms\histograma_299048.png
# Descargado histogramas\weibull_histograms\histograma_880144.png
# Descargado histogramas\exponential_histograms\histograma_59841.png

# %% [markdown]
# ### BOXPLOT CONTINUA

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import os

def generar_boxplot_aleatorio(carpeta_destino):
    distribuciones = ['normal', 'uniform', 'exponential', 'gamma', 'lognormal', 'weibull', 'chi_squared', 'random']
    distribucion_elegida = random.choice(distribuciones)
    
    if distribucion_elegida == 'normal':
        media = random.uniform(-5, 5)
        desviacion = random.uniform(0.5, 3)
        datos = np.random.normal(media, desviacion, 1000)
        folder_path = 'normal_boxplots'
    elif distribucion_elegida == 'uniform':
        inicio = random.uniform(-10, 0)
        fin = random.uniform(0, 10)
        datos = np.random.uniform(inicio, fin, 1000)
        folder_path = 'uniform_boxplots'
    elif distribucion_elegida == 'exponential':
        escala = random.uniform(0.5, 2)
        datos = np.random.exponential(escala, 1000)
        folder_path = 'exponential_boxplots'
    elif distribucion_elegida == 'gamma':
        forma = random.uniform(1, 5)
        escala = random.uniform(0.5, 2)
        datos = np.random.gamma(forma, escala, 1000)
        folder_path = 'gamma_boxplots'
    elif distribucion_elegida == 'lognormal':
        media = random.uniform(-2, 2)
        sigma = random.uniform(0.1, 1)
        datos = np.random.lognormal(media, sigma, 1000)
        folder_path = 'lognormal_boxplots'
    elif distribucion_elegida == 'weibull':
        forma = random.uniform(1, 5)
        escala = random.uniform(0.5, 2)
        datos = np.random.weibull(forma, 1000) * escala
        folder_path = 'weibull_boxplots'
    elif distribucion_elegida == 'chi_squared':
        grados_libertad = random.randint(1, 10)
        datos = np.random.chisquare(grados_libertad, 1000)
        folder_path = 'chi_squared_boxplots'
    elif distribucion_elegida == 'random':
        datos = np.random.rand(1000)  # Completely random data
        folder_path = 'random_boxplots'
    else:
        raise ValueError("Invalid distribution")
    
    color = np.random.rand(3,)
    
    
    # Define los colores para cada parte del boxplot
    boxplot_colors = {
        'boxes': color,
        'whiskers': color,
        'medians': color,
        'caps': color,
        'fliers': color,
        'means': color
    }
    
    # Crea el boxplot con colores
    plt.boxplot(datos, patch_artist=True, boxprops=dict(facecolor=color), capprops=dict(color=color),
                whiskerprops=dict(color=color), flierprops=dict(color=color, markeredgecolor=color),
                medianprops=dict(color=color), meanprops=dict(color=color))
    plt.boxplot(datos)
    plt.title(f'Boxplot Aleatorio ({distribucion_elegida.capitalize()})')
    plt.ylabel('Valor')
    
    carpeta_destino=os.path.join(carpeta_destino,folder_path)
    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)
    nombre_archivo = f'boxplot_{random.randint(1, 1000000)}.png'
    nombre_archivo=os.path.join(carpeta_destino,nombre_archivo)
    borrar_archivo(nombre_archivo)  # Solo si existe
    plt.savefig(nombre_archivo)
    plt.close()
    

    return nombre_archivo

# %%
def descargar_boxplots(num_descargas, carpeta_destino):

    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)

    
    for i in range(num_descargas):
        nombre_archivo = generar_boxplot_aleatorio(carpeta_destino)
        
        ruta_destino = os.path.join(carpeta_destino, nombre_archivo)
        print(f"Descargado {ruta_destino}")

# %%
os.chdir('c:\\Users\\LOLI\\Desktop\\ICAI\\2º SEMESTRE\\NO ESTRUCURADOS\\TRABAJO FINAL\\ADNE\\data')

carpeta_destino='boxplots'
num_descargas=5000
descargar_boxplots(num_descargas,carpeta_destino)
# Out:
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_771967.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_65348.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_20564.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_893075.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_912123.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_108912.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_529973.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_648985.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_764489.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_119427.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_214694.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_396057.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_333409.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_585559.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_979767.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_868787.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_265847.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_532672.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_94687.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_810083.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_766414.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_234588.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_455191.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_80405.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_231040.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_568317.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_651152.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_654311.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_834102.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_48151.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_516003.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_390818.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_664099.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_404594.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_130207.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_70578.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_263977.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_646887.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_322716.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_31423.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_720595.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_456900.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_666325.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_857754.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_130118.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_424682.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_162161.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_968735.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_923591.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_442575.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_860152.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_573032.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_836639.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_315812.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_111919.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_979220.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_269275.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_537881.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_653003.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_497837.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_436816.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_817707.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_258292.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_976561.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_229035.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_496923.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_804151.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_480220.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_128895.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_978617.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_855509.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_682788.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_721022.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_428481.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_870122.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_164436.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_975947.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_208387.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_685074.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_318032.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_602310.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_396264.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_84218.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_235734.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_962143.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_573906.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_930662.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_348160.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_549316.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_961386.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_812283.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_10390.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_626350.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_29375.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_855638.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_618182.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_687821.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_722796.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_347148.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_894228.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_920382.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_451744.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_375666.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_480620.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_848925.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_297112.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_995225.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_412432.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_210546.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_542961.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_138847.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_908942.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_166483.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_210682.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_617230.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_362151.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_353373.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_802938.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_606397.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_700862.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_142810.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_70977.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_154181.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_763622.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_478388.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_569024.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_104927.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_567047.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_718664.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_150625.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_479123.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_268042.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_653844.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_858871.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_76706.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_879678.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_524785.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_432899.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_939978.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_39481.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_752290.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_143386.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_777958.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_272964.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_895877.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_875270.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_730759.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_958707.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_349488.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_307331.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_767893.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_628265.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_109991.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_252435.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_298810.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_568516.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot
png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_364970.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_888166.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_312033.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_34006.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_535396.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_496968.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_635344.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_26588.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_826164.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_133369.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_726640.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_751930.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_537195.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_94668.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_4162.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_416838.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_650868.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_952183.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_292237.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_68180.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_644176.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_105466.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_748294.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_857787.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_827304.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_353729.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_396736.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_856811.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_840609.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_960174.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_717830.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_467821.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_100947.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_214062.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_723078.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_737180.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_682567.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_138000.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_378772.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_905279.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_962591.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_445188.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_322993.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_514074.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_175937.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_183737.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_60610.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_354170.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_229330.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_118333.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_629863.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_325258.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_443523.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_977480.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_934388.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_824346.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_797364.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_681651.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_172034.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_164776.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_827748.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_832404.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_105119.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_375746.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_484755.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_55784.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_284485.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_580421.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_233976.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_521241.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_328015.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_9498.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_299047.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_914382.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_905199.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_90098.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_753750.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_252993.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_735672.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_615137.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_922417.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_423229.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_691810.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_452909.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_703932.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_837240.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_661140.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_67532.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_18091.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_731080.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_157838.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_560363.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_264960.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_944096.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_527342.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_234873.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_53869.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_566161.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_41604.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_382386.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_722862.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_364015.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_59186.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_848601.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_12687.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_523498.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_26095.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_68303.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_400659.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_314341.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_712122.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_562196.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_76917.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_344637.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_183322.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_165350.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_585050.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_963277.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_66038.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_440825.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_914739.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_368414.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_681679.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_918255.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_938444.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_746424.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_769736.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_694826.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_508158.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_765548.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_95166.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_187147.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_561309.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_40483.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_774504.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_678525.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_932572.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_167869.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_25300.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_555584.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_117796.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_819949.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_853077.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_719501.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_375811.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_253855.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_32523.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_543831.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_854720.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_579794.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_239822.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_506058.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_140819.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_526831.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_608327.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_802789.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_650726.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_807068.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_562822.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_665426.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_90171.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_839490.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_552336.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_561893.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_179958.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_58037.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_115419.png
# Descargado boxplots\boxplots\random_boxplots\boxplot_39805.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_429562.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_571724.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_859693.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_968434.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_258030.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_486708.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_708830.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_77188.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_427843.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_98831.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_821312.png
# Descargado boxplots\boxplots\chi_squared_boxplots\boxplot_589874.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_765303.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_708394.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_521078.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_390404.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_306677.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_620020.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_728002.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_671942.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_595177.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_785627.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_285019.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_752494.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_340036.png
# Descargado boxplots\boxplots\normal_boxplots\boxplot_428203.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_984980.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_315801.png
# Descargado boxplots\boxplots\gamma_boxplots\boxplot_733323.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_757650.png
# Descargado boxplots\boxplots\exponential_boxplots\boxplot_692216.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_965396.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_433252.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_393415.png
# Descargado boxplots\boxplots\weibull_boxplots\boxplot_785349.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_801207.png
# Descargado boxplots\boxplots\uniform_boxplots\boxplot_460946.png
# Descargado boxplots\boxplots\lognormal_boxplots\boxplot_958395.png

# %% [markdown]
# ## BOXPLOT CONTINUA VS CATEGÓRICA

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
 
import numpy as np
import random
import matplotlib.pyplot as plt

def generar_boxplot_aleatorio_cont_vs_cat1():
    # Generate random data for categorical variable
    #In this case, all categories will folow the same distribution but with distinct parameters

    num_categorias = random.randint(2, 5)  # Random number of categories between 2 and 5
    categorias = [f'Category_{i}' for i in range(1, num_categorias + 1)]  # Random category labels
    datos_cat = np.random.choice(categorias, size=100)
    
    # Create a dictionary to store data for each category
    data_dict = {}
    for cat in categorias:
        # Generate random data for continuous variable
        distribuciones_cont = ['normal', 'uniform', 'exponential', 'gamma', 'lognormal', 'poisson', 'bernoulli', 'binomial', 'weibull', 'chi_squared', 'random']
        distribucion_cont_elegida = random.choice(distribuciones_cont)
        
        if distribucion_cont_elegida == 'normal':
            media = random.uniform(-5, 5)
            desviacion = random.uniform(0.5, 3)
            datos_cont = np.random.normal(media, desviacion, 100)
        elif distribucion_cont_elegida == 'uniform':
            inicio = random.uniform(-10, 0)
            fin = random.uniform(0, 10)
            datos_cont = np.random.uniform(inicio, fin, 100)
        elif distribucion_cont_elegida == 'exponential':
            escala = random.uniform(0.5, 2)
            datos_cont = np.random.exponential(escala, 100)
        elif distribucion_cont_elegida == 'gamma':
            forma = random.uniform(1, 5)
            escala = random.uniform(0.5, 2)
            datos_cont = np.random.gamma(forma, escala, 100)
        elif distribucion_cont_elegida == 'lognormal':
            media = random.uniform(-2, 2)
            sigma = random.uniform(0.1, 1)
            datos_cont = np.random.lognormal(media, sigma, 100)
        elif distribucion_cont_elegida == 'poisson':
            lambda_ = random.uniform(1, 10)
            datos_cont = np.random.poisson(lambda_, 100)
        elif distribucion_cont_elegida == 'bernoulli':
            p = random.uniform(0.1, 0.9)
            datos_cont = np.random.choice([0, 1], size=100, p=[1-p, p])
        elif distribucion_cont_elegida == 'binomial':
            n = random.randint(5, 20)
            p = random.uniform(0.1, 0.9)
            datos_cont = np.random.binomial(n, p, 100)
        elif distribucion_cont_elegida == 'weibull':
            forma = random.uniform(1, 5)
            escala = random.uniform(0.5, 2)
            datos_cont = np.random.weibull(forma, 100) * escala
        elif distribucion_cont_elegida == 'chi_squared':
            grados_libertad = random.randint(1, 10)
            datos_cont = np.random.chisquare(grados_libertad, 100)
        elif distribucion_cont_elegida == 'random':
            datos_cont = np.random.rand(100)  # Completely random data
        else:
            raise ValueError("Invalid continuous distribution")
        
        data_dict[cat] = datos_cont
    

   # Crear una paleta de colores
    colores = plt.cm.viridis(np.linspace(0, 1, num_categorias))
    
    # Crear el boxplot con colores para cada caja
    fig, ax = plt.subplots()
    boxplot = ax.boxplot([data_dict[cat] for cat in categorias], labels=categorias, patch_artist=True)
    
    # Iterar sobre las cajas y asignar un color a cada una
    for box, color in zip(boxplot['boxes'], colores):
        box.set_facecolor(color)
    # Create boxplot
    plt.boxplot([data_dict[cat] for cat in categorias], labels=categorias)
    plt.title(f'Boxplot Aleatorio (Continuous vs Categorical)')
    plt.xlabel('Category')
    plt.ylabel('Value')
    
    nombre_archivo = f'boxplot_cont_vs_cat_{random.randint(1, 1000000)}.png'
    borrar_archivo(nombre_archivo)
    plt.savefig(nombre_archivo)
    plt.close()
    
    return nombre_archivo

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

def generar_boxplot_aleatorio_cont_vs_cat2():
    # Generate random data for categorical variable
    #In this case every category will follow a different distribution
    num_categorias = random.randint(2, 5)  # Random number of categories between 2 and 5
    categorias = [f'Category_{i}' for i in range(1, num_categorias + 1)]  # Random category labels
    datos_cat = np.random.choice(categorias, size=100)
    
    # Create a dictionary to store data for each category
    data_dict = {}
    for cat in categorias:
        # Generate random data for continuous variable
        distribuciones_cont = ['normal', 'uniform', 'exponential', 'gamma', 'lognormal',  'weibull', 'chi_squared']
        distribucion_cont_elegida = random.choice(distribuciones_cont)
        
        if distribucion_cont_elegida == 'normal':
            media = random.uniform(-5, 5)
            desviacion = random.uniform(0.5, 3)
            datos_cont = np.random.normal(media, desviacion, 100)
        elif distribucion_cont_elegida == 'uniform':
            inicio = random.uniform(-10, 0)
            fin = random.uniform(0, 10)
            datos_cont = np.random.uniform(inicio, fin, 100)
        elif distribucion_cont_elegida == 'exponential':
            escala = random.uniform(0.5, 2)
            datos_cont = np.random.exponential(escala, 100)
        elif distribucion_cont_elegida == 'gamma':
            forma = random.uniform(1, 5)
            escala = random.uniform(0.5, 2)
            datos_cont = np.random.gamma(forma, escala, 100)
        elif distribucion_cont_elegida == 'lognormal':
            media = random.uniform(-2, 2)
            sigma = random.uniform(0.1, 1)
            datos_cont = np.random.lognormal(media, sigma, 100)
        elif distribucion_cont_elegida == 'weibull':
            forma = random.uniform(1, 5)
            escala = random.uniform(0.5, 2)
            datos_cont = np.random.weibull(forma, 100) * escala
        elif distribucion_cont_elegida == 'chi_squared':
            grados_libertad = random.randint(1, 10)
            datos_cont = np.random.chisquare(grados_libertad, 100)
        else:
            raise ValueError("Invalid continuous distribution")
        
        data_dict[cat] = datos_cont
    
   # Crear una paleta de colores
    colores = plt.cm.viridis(np.linspace(0, 1, num_categorias))
    
    # Crear el boxplot con colores para cada caja
    fig, ax = plt.subplots()
    boxplot = ax.boxplot([data_dict[cat] for cat in categorias], labels=categorias, patch_artist=True)
    
    # Iterar sobre las cajas y asignar un color a cada una
    for box, color in zip(boxplot['boxes'], colores):
        box.set_facecolor(color)
    # Create boxplot
    plt.boxplot([data_dict[cat] for cat in categorias], labels=categorias)
    plt.title('Boxplot Aleatorio (Continuous vs Categorical)')
    plt.xlabel('Category')
    plt.ylabel('Value')
    
    nombre_archivo = f'boxplot_cont_vs_cat_{random.randint(1, 1000000)}.png'
    plt.savefig(nombre_archivo)
    plt.close()
    
    return nombre_archivo

# %%
def descargar_boxplots_cont_vs_cat(num_descargas, carpeta_destino):

    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)

    

    for i in range(num_descargas):
        u=np.random.uniform(0,1)
        if u<0.3:
            nombre_archivo = generar_boxplot_aleatorio_cont_vs_cat1()
        else:
            nombre_archivo = generar_boxplot_aleatorio_cont_vs_cat2()
        
        ruta_destino = os.path.join(carpeta_destino, nombre_archivo)
        os.rename(nombre_archivo, ruta_destino)
        print(f"Descargado {ruta_destino}")

# %%
os.chdir('c:\\Users\\LOLI\\Desktop\\ICAI\\2º SEMESTRE\\NO ESTRUCURADOS\\TRABAJO FINAL\\ADNE\\data')

carpeta_destino='boxplots_con_vs_cat'
num_descargas=1000
descargar_boxplots_cont_vs_cat(num_descargas,carpeta_destino)
# Out:
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_10532.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_382611.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_504531.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_412118.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_984224.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_610213.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_937616.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_482038.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_903179.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_890156.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_40738.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_807910.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_46318.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_641340.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_100842.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_75802.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat
png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_128170.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_954850.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_973503.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_882877.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_340940.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_619483.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_320661.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_108215.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_638346.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_28913.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_390997.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_518703.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_290916.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_168861.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_284372.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_746946.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_829774.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_610091.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_338522.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_268735.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_470696.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_195704.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_435294.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_698757.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_334066.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_954897.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_362476.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_222225.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_722345.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_1081.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_601646.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_305441.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_652729.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_847186.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_941565.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_69835.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_402466.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_390330.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_910182.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_696444.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_600129.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_581930.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_979511.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_360589.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_94438.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_592915.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_76722.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_268077.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_43269.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_376236.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_256569.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_373242.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_623724.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_14253.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_47930.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_110657.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_662344.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_324824.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_317354.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_506295.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_955711.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_69067.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_360995.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_411047.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_81429.png
# Descargado boxplots_con_vs_cat\boxplot_cont_vs_cat_244691.png

# %%
### Barplots una sola variable

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import os
from collections import Counter

def absolute_frequency(numbers):
    freq_counter = Counter(numbers)
    freq_dict = dict(freq_counter)
    return freq_dict

def generar_barplot_aleatorio_cat(carpeta_destino):
    # Generate random data for the categorical variable
    num_categories = random.randint(2, 7)  # Random number of categories between 3 and 7
    categories = [f'Category_{i}' for i in range(1, num_categories + 1)]  # Random category labels
    
    # Choose a random distribution for the categorical variable
    distributions = ['bernoulli', 'binomial', 'poisson', 'geometric', 'random']
    distribution = random.choice(distributions)
    
    # Generate random samples based on the chosen distribution
    if distribution == 'bernoulli':
        p = random.uniform(0.1, 0.9)
        samples = np.random.choice([0, 1], size=random.randint(10, 50), p=[1-p, p])
        folder_path = 'bernoulli_barplots'
    elif distribution == 'binomial':
        n = random.randint(5, 20)
        p = random.uniform(0.1, 0.9)
        samples = np.random.binomial(n, p, size=random.randint(10, 50))
        folder_path = 'binomial_barplots'
    elif distribution == 'poisson':
        lambda_ = random.uniform(1, 10)
        samples = np.random.poisson(lambda_, size=random.randint(10, 50))
        folder_path = 'poisson_barplots'
    elif distribution == 'geometric':
        p = random.uniform(0.1, 0.9)
        samples = np.random.geometric(p, size=random.randint(10, 50))
        folder_path = 'geometric_barplots'
    elif distribution == 'random':
        samples = np.random.randint(1, 50, size=random.randint(10, 50))
        folder_path = 'random_barplots'
    else:
        raise ValueError("Invalid categorical distribution")
    
    # Calculate absolute frequency of each sample
    freq_dict = absolute_frequency(samples)
    
    # Generate random colors for the bars
    bar_colors = [tuple(np.random.rand(3)) for _ in range(len(freq_dict))]
    
    # Create bar plot
    plt.bar(freq_dict.keys(), freq_dict.values(), color=bar_colors)
    plt.title('Barplot Aleatorio (Categorical)')
    plt.xlabel('Categories')
    plt.ylabel('Frequency')
    
    # Set x-tick labels to only show categories in freq_dict
    plt.xticks(list(freq_dict.keys()))
    
    # Save the plot
    carpeta_destino = os.path.join(carpeta_destino, folder_path)
    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)
    nombre_archivo = f'barplot_cat_{random.randint(1, 1000000)}.png'
    nombre_archivo = os.path.join(carpeta_destino, nombre_archivo)
    plt.savefig(nombre_archivo)
    plt.close()
    
    return nombre_archivo

# %%
def descargar_barplots(num_descargas, carpeta_destino):

    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)    

    for i in range(num_descargas):
        nombre_archivo=generar_barplot_aleatorio_cat(carpeta_destino)
        ruta_destino = os.path.join(carpeta_destino, nombre_archivo)
        print(f"Descargado {ruta_destino}")

# %%
os.chdir('c:\\Users\\LOLI\\Desktop\\ICAI\\2º SEMESTRE\\NO ESTRUCURADOS\\TRABAJO FINAL\\ADNE\\data')

carpeta_destino='barplots'
num_descargas=5000
descargar_barplots(num_descargas,carpeta_destino)
# Out:
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_781595.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_177450.png
# Descargado barplots\barplots\random_barplots\barplot_cat_90280.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_39353.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_445818.png
# Descargado barplots\barplots\random_barplots\barplot_cat_779255.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_805593.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_925650.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_404568.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_327026.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_652628.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_208482.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_557095.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_357864.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_464273.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_358287.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_489298.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_497422.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_124913.png
# Descargado barplots\barplots\random_barplots\barplot_cat_648130.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_586635.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_969678.png
# Descargado barplots\barplots\random_barplots\barplot_cat_662358.png
# Descargado barplots\barplots\random_barplots\barplot_cat_223503.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_898500.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_726762.png
# Descargado barplots\barplots\random_barplots\barplot_cat_92891.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_499488.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_920805.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_917476.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_122615.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_125194.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_737465.png
# Descargado barplots\barplots\random_barplots\barplot_cat_956949.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_858014.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_561290.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_307493.png
# Descargado barplots\barplots\random_barplots\barplot_cat_623616.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_392313.png
# Descargado barplots\barplots\random_barplots\barplot_cat_257766.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_221385.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_452656.png
# Descargado barplots\barplots\random_barplots\barplot_cat_781428.png
# Descargado barplots\barplots\random_barplots\barplot_cat_676320.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_699058.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_928289.png
# Descargado barplots\barplots\random_barplots\barplot_cat_594503.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_991545.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_327854.png
# Descargado barplots\barplots\random_barplots\barplot_cat_905632.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_755040.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_740062.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_30810.png
# Descargado barplots\barplots\random_barplots\barplot_cat_258868.png
# Descargado barplots\barplots\random_barplots\barplot_cat_964568.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_144835.png
# Descargado barplots\barplots\random_barplots\barplot_cat_4656.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_26032.png
# Descargado barplots\barplots\random_barplots\barplot_cat_774098.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_138014.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_513013.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_501824.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_17741.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_30711.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_956273.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_41416.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_526187.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_419587.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_425773.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_633351.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_766844.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_789841.png
# Descargado barplots\barplots\random_barplots\barplot_cat_718658.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_974770.png
# Descargado barplots\barplots\random_barplots\barplot_cat_502346.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_555770.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_937455.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_479280.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_85441.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_658263.png
# Descargado barplots\barplots\random_barplots\barplot_cat_997662.png
# Descargado barplots\barplots\random_barplots\barplot_cat_237169.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_931969.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_383161.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_319015.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_190081.png
# Descargado barplots\barplots\random_barplots\barplot_cat_962600.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_834213.png
# Descargado barplots\barplots\random_barplots\barplot_cat_499603.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_332743.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_209811.png
# Descargado barplots\barplots\random_barplots\barplot_cat_605842.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_704879.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_530260.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_959198.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_820000.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_285830.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_420447.png
# Descargado barplots\barplots\random_barplots\barplot_cat_770824.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_898437.png
# Descargado barplots\barplots\random_barplots\barplot_cat_798635.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_935454.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_563916.png
# Descargado barplots\barplots\random_barplots\barplot_cat_188732.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_925068.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_83070.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_126609.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_974136.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_727711.png
# Descargado barplots\barplots\random_barplots\barplot_cat_833911.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_777979.png
# Descargado barplots\barplots\random_barplots\barplot_cat_984294.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_295041.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_403014.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_681997.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_508970.png
# Descargado barplots\barplots\random_barplots\barplot_cat_831980.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_794880.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_580987.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_973969.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_256502.png
# Descargado barplots\barplots\random_barplots\barplot_cat_12472.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_314419.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_189632.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_315262.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_869417.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_346013.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_510542.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_199534.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_344170.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_20648.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_109431.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_658371.png
# Descargado barplots\barplots\random_barplots\barplot_cat_385863.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_290049.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_544154.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_75697.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_572660.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_539380.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_182018.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_445895.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_928491.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_794076.png
# Descargado barplots\barplots\random_barplots\barplot_cat_911528.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_748110.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_60227.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_869828.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_433950.png
# Descargado barplots\barplots\random_barplots\barplot_cat_541079.png
# Descargado barplots\barplots\random_barplots\barplot_cat_270341.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_40614.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_492646.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_944806.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_690628.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_440664.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_381841.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_360617.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_622371.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_420946.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_755774.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_202073.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_731329.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_575919.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_251524.png
# Descargado barplots\barplots\random_barplots\barplot_cat_787826.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_533375.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_64833.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_795521.png
# Descargado barplots\barplots\random_barplots\barplot_cat_362657.png
# Descargado barplots\barplots\random_barplots\barplot_cat_68408.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_104134.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_246288.png
# Descargado barplots\barplots\random_barplots\barplot_cat_884260.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_326400.png
# Descargado barplots\barplots\random_barplots\barplot_cat_910309.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_907045.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_274818.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_409605.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_636479.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_745278.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_777566.png
# Descargado barplots\barplots\random_barplots\barplot_cat_860852.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_875850.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_24431.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_843886.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_940035.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_241466.png
# Descargado barplots\barplots\random_barplots\barplot_cat_885125.png
# Descargado barplots\barplots\random_barplots\barplot_cat_694090.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_885179.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_669597.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_481980.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_644496.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_308930.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_845508.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_340445.png
# Descargado barplots\barplots\random_barplots\barplot_cat_874636.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_851176.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_410075.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_894125.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_594236.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_208244.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_164965.png
# Descargado barplots\barplots\random_barplots\barplot_cat_719750.png
# Descargado barplots\barplots\random_barplots\barplot_cat_695777.png
# Descargado barplots\barplots\random_barplots\barplot_cat_55554.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_958922.png
# Descargado barplots\barplots\random_barplots\barplot_cat_282345.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_391052.png
# Descargado barplots\barplots\random_barplots\barplot_cat_471227.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_370926.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_535356.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_827520.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_294188.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_801551.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_109843.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_579856.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_394351.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_834622.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_792278.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_873603.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_79306.png
# Descargado barplots\barplots\random_barplots\barplot_cat_972966.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_648639.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_379745.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_651118.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_723755.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_697993.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_490995.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_811566.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_360999.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_724414.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_48481.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_602729.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_843369.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_487415.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_44493.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_573686.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_960538.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_961993.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_11112.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_747886.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_532577.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_713745.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_858656.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_74635.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_994470.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_29808.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_499407.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_954766.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_420470.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_222290.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_137520.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_593146.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_963215.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_259426.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_143848.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_292216.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_17151.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_335224.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_135734.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_1781.png
# Descargado barplots\barplots\random_barplots\barplot_cat_677365.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_978112.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_154471.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_64070.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_5895.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_428436.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_940608.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_330527.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_83785.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_782567.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_539988.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_752205.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_665058.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_570343.png
# Descargado barplots\barplots\random_barplots\barplot_cat_437732.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_113118.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_912319.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_357022.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_630298.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_258422.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_913627.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_675264.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_801036.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_605344.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_261526.png
# Descargado barplots\barplots\random_barplots\barplot_cat_329482.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_999371.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_759543.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_863033.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_911418.png
# Descargado barplots\barplots\random_barplots\barplot_cat_446507.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_878734.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_784367.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_42659.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_776852.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_99999.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_778662.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_779300.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_592127.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_65916.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_597938.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_798318.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_333804.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_348345.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_850745.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_886571.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_265786.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_397474.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_904073.png
# Descargado barplots\barplots\random_barplots\barplot_cat_3856.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_121310.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_614302.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_990179.png
# Descargado barplots\barplots\random_barplots\barplot_cat_742303.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_647683.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_626446.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_359887.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_877817.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_745990.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_812862.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_750345.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_874154.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_382320.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_917868.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_335632.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_111919.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_399966.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_729071.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_757558.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_394477.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_281130.png
# Descargado barplots\barplots\random_barplots\barplot_cat_131920.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_443261.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_987991.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_778777.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_318560.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_786089.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_924942.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_879444.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_654171.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_784980.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_648928.png
# Descargado barplots\barplots\random_barplots\barplot_cat_668999.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_884037.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_749268.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_850232.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_269651.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_569028.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_543854.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_387710.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_896848.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_223470.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_291434.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_396489.png
# Descargado barplots\barplots\random_barplots\barplot_cat_634848.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_349161.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_734338.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_659105.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_729886.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_685712.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_878393.png
# Descargado barplots\barplots\random_barplots\barplot_cat_453332.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_971035.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_776800.png
# Descargado barplots\barplots\random_barplots\barplot_cat_333870.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_590459.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_461902.png
# Descargado barplots\barplots\random_barplots\barplot_cat_249320.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_917496.png
# Descargado barplots\barplots\random_barplots\barplot_cat_286724.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_454359.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_599305.png
# Descargado barplots\barplots\random_barplots\barplot_cat_299004.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_769058.png
# Descargado barplots\barplots\random_barplots\barplot_cat_4434.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_721765.png
# Descargado barplots\barplots\random_barplots\barplot_cat_897701.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_921645.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_802800.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_367259.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_485684.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_316735.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_428922.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_63878.png
# Descargado barplots\barplots\random_barplots\barplot_cat_515407.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_18620.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_526309.png
# Descargado barplots\barplots\random_barplots\barplot_cat_604881.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_470503.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_921916.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_554447.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_344891.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_941831.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_59546.png
# Descargado barplots\barplots\random_barplots\barplot_cat_862864.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_588647.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_27669.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_786559.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_465482.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_191489.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_307146.png
# Descargado barplots\barplots\random_barplots\barplot_cat_240595.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_963812.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_76798.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_138605.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_540822.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_519547.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_638955.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_429239.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_300355.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_155537.png
# Descargado barplots\barplots\random_barplots\barplot_cat_895290.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_370802.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_258012.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_900163.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_300446.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_114860.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_595936.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_308981.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_508105.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_849699.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_228816.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_83417.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_376595.png
# Descargado barplots\barplots\random_barplots\barplot_cat_431314.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_395492.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_105262.png
# Descargado barplots\barplots\random_barplots\barplot_cat_482458.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_960042.png
# Descargado barplots\barplots\random_barplots\barplot_cat_269971.png
# Descargado barplots\barplots\random_barplots\barplot_cat_90344.png
# Descargado barplots\barplots\random_barplots\barplot_cat_55632.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_129491.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_766021.png
# Descargado barplots\barplots\random_barplots\barplot_cat_91643.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_164392.png
# Descargado barplots\barplots\random_barplots\barplot_cat_915270.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_47252.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_588028.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_589524.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_701293.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_477332.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_188750.png
# Descargado barplots\barplots\random_barplots\barplot_cat_653686.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_433247.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_739716.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_727232.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_157239.png
# Descargado barplots\barplots\random_barplots\barplot_cat_91192.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_112413.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_586144.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_257582.png
# Descargado barplots\barplots\random_barplots\barplot_cat_598735.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_718709.png
# Descargado barplots\barplots\random_barplots\barplot_cat_906887.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_561816.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_434063.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_346602.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_373902.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_707835.png
# Descargado barplots\barplots\random_barplots\barplot_cat_286433.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_856192.png
# Descargado barplots\barplots\random_barplots\barplot_cat_965905.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_227356.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_586989.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_381845.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_253454.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_289827.png
# Descargado barplots\barplots\random_barplots\barplot_cat_560945.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_893033.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_516496.png
# Descargado barplots\barplots\random_barplots\barplot_cat_668498.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_429616.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_274676.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_335327.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_837404.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_958890.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_640927.png
# Descargado barplots\barplots\random_barplots\barplot_cat_613587.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_450995.png
# Descargado barplots\barplots\random_barplots\barplot_cat_453869.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_332099.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_647795.png
# Descargado barplots\barplots\random_barplots\barplot_cat_896837.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_773052.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_889911.png
# Descargado barplots\barplots\random_barplots\barplot_cat_468492.png
# Descargado barplots\barplots\random_barplots\barplot_cat_267380.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_682067.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_722587.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_772333.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_594359.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_189328.png
# Descargado barplots\barplots\random_barplots\barplot_cat_499492.png
# Descargado barplots\barplots\random_barplots\barplot_cat_825660.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_85396.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_847660.png
# Descargado barplots\barplots\random_barplots\barplot_cat_890174.png
# Descargado barplots\barplots\random_barplots\barplot_cat_803810.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_348824.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_541893.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_268196.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_872252.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_412516.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_347795.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_813931.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_778477.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_661153.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_699662.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_486831.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_667481.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_547823.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_486396.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_86965.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_461439.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_360936.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_832394.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_666210.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_975190.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_646305.png
# Descargado barplots\barplots\random_barplots\barplot_cat_88229.png
# Descargado barplots\barplots\random_barplots\barplot_cat_191771.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_91328.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_425638.png
# Descargado barplots\barplots\random_barplots\barplot_cat_25695.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_527308.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_149532.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_251908.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_236360.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_257288.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_565580.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_123473.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_761076.png
# Descargado barplots\barplots\random_barplots\barplot_cat_350002.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_148585.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_733015.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_911534.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_560773.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_191471.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_883930.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_727519.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_616620.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_916878.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_460604.png
# Descargado barplots\barplots\random_barplots\barplot_cat_430218.png
# Descargado barplots\barplots\random_barplots\barplot_cat_882162.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_226596.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_236680.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_87594.png
# Descargado barplots\barplots\random_barplots\barplot_cat_662465.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_917955.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_53632.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_66744.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_227226.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_525642.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_292342.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_496056.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_844201.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_361093.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_507323.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_746511.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_114193.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_189732.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_454852.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_631183.png
# Descargado barplots\barplots\random_barplots\barplot_cat_930057.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_799054.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_892742.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_605716.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_502867.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_30577.png
# Descargado barplots\barplots\random_barplots\barplot_cat_974785.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_730343.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_519072.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_455762.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_281214.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_410291.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_996872.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_438139.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_680909.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_340144.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_523906.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_30989.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_671663.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_401242.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_809031.png
# Descargado barplots\barplots\random_barplots\barplot_cat_988610.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_270940.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_179221.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_831084.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_49166.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_825990.png
# Descargado barplots\barplots\random_barplots\barplot_cat_39168.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_187550.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_234871.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_545275.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_54753.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_76991.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_158148.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_988101.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_663535.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_14877.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_603396.png
# Descargado barplots\barplots\random_barplots\barplot_cat_405406.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_791828.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_771693.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_609127.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_508232.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_792807.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_775144.png
# Descargado barplots\barplots\random_barplots\barplot_cat_512112.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_662009.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_137292.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_356627.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_529348.png
# Descargado barplots\barplots\random_barplots\barplot_cat_226641.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_693250.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_493794.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_23205.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_757189.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_329093.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_668829.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_553318.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_47257.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_118278.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_112936.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_380717.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_268575.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_624477.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_834218.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_248805.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_919520.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_409630.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_999113.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_992229.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_204090.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_56379.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_968407.png
# Descargado barplots\barplots\random_barplots\barplot_cat_316939.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_773473.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_88984.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_201355.png
# Descargado barplots\barplots\random_barplots\barplot_cat_656294.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_429704.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_852708.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_430140.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_146515.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_373825.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_342987.png
# Descargado barplots\barplots\random_barplots\barplot_cat_864380.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_260370.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_789918.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_64859.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_736087.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_68219.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_251073.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_203790.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_950337.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_484687.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_80724.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_579331.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_354978.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_38098.png
# Descargado barplots\barplots\random_barplots\barplot_cat_347257.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_359466.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_706615.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_226984.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_903232.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_570595.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_22927.png
# Descargado barplots\barplots\random_barplots\barplot_cat_588836.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_939803.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_862240.png
# Descargado barplots\barplots\random_barplots\barplot_cat_203418.png
# Descargado barplots\barplots\random_barplots\barplot_cat_109685.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_808960.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_883733.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_132988.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_468390.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_297630.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_747140.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_860351.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_135325.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_930907.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_849516.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_266244.png
# ...
# Descargado barplots\barplots\binomial_barplots\barplot_cat_20868.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_646631.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_217028.png
# Descargado barplots\barplots\random_barplots\barplot_cat_289438.png
# Descargado barplots\barplots\random_barplots\barplot_cat_619829.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_398787.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_483178.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_91627.png
# Descargado barplots\barplots\random_barplots\barplot_cat_519668.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_28771.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_591534.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_251963.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_809309.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_320103.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_124000.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_482304.png
# Descargado barplots\barplots\random_barplots\barplot_cat_396793.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_250761.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_5337.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_733472.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_428808.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_930732.png
# Descargado barplots\barplots\random_barplots\barplot_cat_262107.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_787649.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_52042.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_144960.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_967036.png
# Descargado barplots\barplots\random_barplots\barplot_cat_319516.png
# Descargado barplots\barplots\random_barplots\barplot_cat_148158.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_825403.png
# Descargado barplots\barplots\random_barplots\barplot_cat_919246.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_370227.png
# Descargado barplots\barplots\random_barplots\barplot_cat_257852.png
# Descargado barplots\barplots\random_barplots\barplot_cat_323265.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_568382.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_463275.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_221699.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_683214.png
# Descargado barplots\barplots\random_barplots\barplot_cat_37698.png
# Descargado barplots\barplots\random_barplots\barplot_cat_990421.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_295427.png
# Descargado barplots\barplots\random_barplots\barplot_cat_718332.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_511022.png
# Descargado barplots\barplots\random_barplots\barplot_cat_791425.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_101325.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_687158.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_318719.png
# Descargado barplots\barplots\random_barplots\barplot_cat_590763.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_533305.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_451079.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_814045.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_396176.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_283620.png
# Descargado barplots\barplots\random_barplots\barplot_cat_733353.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_584021.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_974205.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_842893.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_873010.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_915734.png
# Descargado barplots\barplots\random_barplots\barplot_cat_350881.png
# Descargado barplots\barplots\random_barplots\barplot_cat_814150.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_49164.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_340459.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_831312.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_125074.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_16226.png
# Descargado barplots\barplots\random_barplots\barplot_cat_40943.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_736689.png
# Descargado barplots\barplots\random_barplots\barplot_cat_553899.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_967630.png
# Descargado barplots\barplots\random_barplots\barplot_cat_865696.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_360091.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_784109.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_140341.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_364887.png
# Descargado barplots\barplots\random_barplots\barplot_cat_416126.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_257391.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_814866.png
# Descargado barplots\barplots\random_barplots\barplot_cat_626992.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_314729.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_277047.png
# Descargado barplots\barplots\random_barplots\barplot_cat_195284.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_693767.png
# Descargado barplots\barplots\random_barplots\barplot_cat_89347.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_357772.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_637607.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_762843.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_188745.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_981172.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_310911.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_840035.png
# Descargado barplots\barplots\random_barplots\barplot_cat_12568.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_126516.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_240892.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_970841.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_660632.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_757848.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_593638.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_361764.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_69568.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_47776.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_323143.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_12575.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_880079.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_586052.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_99648.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_884689.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_135306.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_909144.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_881716.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_118816.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_53541.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_422761.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_696576.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_402751.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_80879.png
# Descargado barplots\barplots\random_barplots\barplot_cat_265922.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_705176.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_772986.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_62731.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_577518.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_640129.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_495414.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_885272.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_950855.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_860157.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_696690.png
# Descargado barplots\barplots\random_barplots\barplot_cat_330470.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_205726.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_172125.png
# Descargado barplots\barplots\random_barplots\barplot_cat_597560.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_651064.png
# Descargado barplots\barplots\random_barplots\barplot_cat_570798.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_652217.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_503623.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_484944.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_845112.png
# Descargado barplots\barplots\random_barplots\barplot_cat_697773.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_667090.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_663670.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_616551.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_276612.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_58122.png
# Descargado barplots\barplots\random_barplots\barplot_cat_567985.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_192229.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_39176.png
# Descargado barplots\barplots\random_barplots\barplot_cat_92873.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_206500.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_474810.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_440538.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_674716.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_503179.png
# Descargado barplots\barplots\random_barplots\barplot_cat_944831.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_121479.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_545248.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_819846.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_586236.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_330157.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_562805.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_801923.png
# Descargado barplots\barplots\random_barplots\barplot_cat_23008.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_426761.png
# Descargado barplots\barplots\random_barplots\barplot_cat_458092.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_749552.png
# Descargado barplots\barplots\random_barplots\barplot_cat_684848.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_662074.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_468829.png
# Descargado barplots\barplots\random_barplots\barplot_cat_670151.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_35530.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_28351.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_359134.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_264695.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_313841.png
# Descargado barplots\barplots\random_barplots\barplot_cat_232534.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_981578.png
# Descargado barplots\barplots\random_barplots\barplot_cat_9139.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_80301.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_320992.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_880576.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_441854.png
# Descargado barplots\barplots\random_barplots\barplot_cat_66611.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_414247.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_428549.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_140349.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_425085.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_621668.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_104163.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_127796.png
# Descargado barplots\barplots\random_barplots\barplot_cat_369290.png
# Descargado barplots\barplots\random_barplots\barplot_cat_898320.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_595890.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_131321.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_720263.png
# Descargado barplots\barplots\random_barplots\barplot_cat_479778.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_696139.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_861825.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_369210.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_560782.png
# Descargado barplots\barplots\random_barplots\barplot_cat_740711.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_822803.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_214927.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_481333.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_919993.png
# Descargado barplots\barplots\random_barplots\barplot_cat_992686.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_784686.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_281828.png
# Descargado barplots\barplots\random_barplots\barplot_cat_635566.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_61167.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_565758.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_81334.png
# Descargado barplots\barplots\random_barplots\barplot_cat_475981.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_905077.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_90154.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_364114.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_844645.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_169350.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_315542.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_186847.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_604889.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_970255.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_912574.png
# Descargado barplots\barplots\random_barplots\barplot_cat_581086.png
# Descargado barplots\barplots\bernoulli_barplots\barplot_cat_32895.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_684651.png
# Descargado barplots\barplots\poisson_barplots\barplot_cat_675172.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_183861.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_838396.png
# Descargado barplots\barplots\geometric_barplots\barplot_cat_207654.png
# Descargado barplots\barplots\binomial_barplots\barplot_cat_875148.png

# %%
 
import random
import matplotlib.pyplot as plt
import os
from collections import Counter

def absolute_frequency(numbers):
    freq_counter = Counter(numbers)
    freq_dict = dict(freq_counter)
    return freq_dict

def generar_pieplot_aleatorio_cat(carpeta_destino):
    # Generate random data for the categorical variable
    num_categories = random.randint(2, 7)  # Random number of categories between 3 and 7
    categories = [f'Category_{i}' for i in range(1, num_categories + 1)]  # Random category labels
    
    # Choose a random distribution for the categorical variable
    distributions = ['bernoulli', 'binomial', 'poisson', 'geometric', 'random']
    distribution = random.choice(distributions)
    
    # Generate random samples based on the chosen distribution
    if distribution == 'bernoulli':
        p = random.uniform(0.1, 0.9)
        samples = np.random.choice([0, 1], size=random.randint(10, 50), p=[1-p, p])
        folder_path = 'bernoulli_pieplots'
    elif distribution == 'binomial':
        n = random.randint(5, 20)
        p = random.uniform(0.1, 0.9)
        samples = np.random.binomial(n, p, size=random.randint(10, 50))
        folder_path = 'binomial_pieplots'
    elif distribution == 'poisson':
        lambda_ = random.uniform(1, 10)
        samples = np.random.poisson(lambda_, size=random.randint(10, 50))
        folder_path = 'poisson_pieplots'
    elif distribution == 'geometric':
        p = random.uniform(0.1, 0.9)
        samples = np.random.geometric(p, size=random.randint(10, 50))
        folder_path = 'geometric_pieplots'
    elif distribution == 'random':
        samples = np.random.randint(1, 50, size=random.randint(10, 50))
        folder_path = 'random_pieplots'
    else:
        raise ValueError("Invalid categorical distribution")
    
    # Calculate absolute frequency of each sample
    freq_dict = absolute_frequency(samples)
    
    # Generate random colors for the slices
    pie_colors = [tuple(np.random.rand(3)) for _ in range(len(freq_dict))]
    
    # Create pie plot
    plt.pie(freq_dict.values(), labels=freq_dict.keys(), colors=pie_colors, startangle=140)
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.title('Pieplot Aleatorio (Categorical)')
    
    # Save the plot
    carpeta_destino = os.path.join(carpeta_destino, folder_path)
    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)
    nombre_archivo = f'pieplot_cat_{random.randint(1, 1000000)}.png'
    nombre_archivo = os.path.join(carpeta_destino, nombre_archivo)
    plt.savefig(nombre_archivo)
    plt.close()
    
    return nombre_archivo

# %%
def descargar_pieplots(num_descargas, carpeta_destino):

    if not os.path.exists(carpeta_destino):
        os.makedirs(carpeta_destino)    

    for i in range(num_descargas):
        nombre_archivo=generar_pieplot_aleatorio_cat(carpeta_destino)
        ruta_destino = os.path.join(carpeta_destino, nombre_archivo)
        print(f"Descargado {ruta_destino}")

# %%
os.chdir('c:\\Users\\LOLI\\Desktop\\ICAI\\2º SEMESTRE\\NO ESTRUCURADOS\\TRABAJO FINAL\\ADNE\\data')

carpeta_destino='pieplots'
num_descargas=5000
descargar_pieplots(num_descargas,carpeta_destino)
# Out:
# Descargado pieplots\pieplots\random_pieplots\pieplot_cat_809334.png
# Descargado pieplots\pieplots\random_pieplots\pieplot_cat_603183.png
# Descargado pieplots\pieplots\binomial_pieplots\pieplot_cat_764719.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_7230.png
# Descargado pieplots\pieplots\binomial_pieplots\pieplot_cat_766168.png
# Descargado pieplots\pieplots\bernoulli_pieplots\pieplot_cat_277661.png
# Descargado pieplots\pieplots\bernoulli_pieplots\pieplot_cat_273491.png
# Descargado pieplots\pieplots\bernoulli_pieplots\pieplot_cat_793036.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_907923.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_794358.png
# Descargado pieplots\pieplots\bernoulli_pieplots\pieplot_cat_320711.png
# Descargado pieplots\pieplots\binomial_pieplots\pieplot_cat_199672.png
# Descargado pieplots\pieplots\geometric_pieplots\pieplot_cat_73721.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_660562.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_614489.png
# Descargado pieplots\pieplots\geometric_pieplots\pieplot_cat_34334.png
# Descargado pieplots\pieplots\random_pieplots\pieplot_cat_495377.png
# Descargado pieplots\pieplots\geometric_pieplots\pieplot_cat_147006.png
# Descargado pieplots\pieplots\binomial_pieplots\pieplot_cat_114608.png
# Descargado pieplots\pieplots\geometric_pieplots\pieplot_cat_603648.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_703357.png
# Descargado pieplots\pieplots\bernoulli_pieplots\pieplot_cat_813519.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_48056.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_528489.png
# Descargado pieplots\pieplots\random_pieplots\pieplot_cat_353242.png
# Descargado pieplots\pieplots\binomial_pieplots\pieplot_cat_960033.png
# Descargado pieplots\pieplots\random_pieplots\pieplot_cat_318894.png
# Descargado pieplots\pieplots\bernoulli_pieplots\pieplot_cat_802159.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_374424.png
# Descargado pieplots\pieplots\poisson_pieplots\pieplot_cat_293138.png
# Descargado pieplots\pieplots\random_pieplots\pieplot_cat_25309.png
# Descargado pieplots\pieplots\geometric_pieplots\pieplot_cat_280824.png
# Descargado pieplots\pieplots\binomial_pieplots\pieplot_cat_227709.png
# Descargado pieplots\pieplots\geometric_pieplots\pieplot_cat